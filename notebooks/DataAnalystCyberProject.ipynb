# %% [markdown]
# # <div dir="rtl"> 🔹שלב 1: הגדרת והפעלת צינור ETL </div>
# <div dir="rtl"> בשלב זה אנו מייבאים ומגדירים את כל הספריות הדרושות ואת החיבור למסד הנתונים, מממשים את הפונקציות load_posted_news ו-load_skipped_news כדי לקרוא, להסיר כפילויות ולסנן רשומות חדשות מקובצי JSON אל תוך DataFrames, ובונים את הפונקציה הראשית כדי לכתוב את המאמרים החדשים לטבלאות PostedNews ו-SkippedNews.</div>

# %% [markdown]
# #### <div dir="rtl"> חלק 1: ייבוא ספריות וחיבור למסד הנתונים </div>
# <div dir="rtl"> ייבוא ספריות מרכזיות לעבודה עם JSON, עיבוד נתונים, גישה למסד נתונים, ויזואליזציה, ניתוח גרפים ו-NLP/למידת מכונה, ולאחר מכן בנייה והפעלה של מנוע SQLAlchemy לצורך חיבור למסד הנתונים CyberNewsBot SQL Server.</div>

# %%
# === Standard Library ===
import json                                 # JSON parsing and serialization
import warnings                             # Suppress or handle library warnings if needed

# === Data Manipulation ===
import pandas as pd                         # Analysis and processing of tabular datasets
import numpy as np                          # Numerical computations and matrix operations

# === Database Connectivity ===
from sqlalchemy import create_engine        # Establish and manage SQL connections
from sqlalchemy.types import NVARCHAR, Date, Time  
                                            # Precise SQL column types for to_sql()

# === Visualization ===
import matplotlib.pyplot as plt             # Core plotting API
import matplotlib.colors as mcolors         # Predefined color palettes and utilities
import matplotlib.cm as cm                  # Colormap registry and mapping functions
from matplotlib.dates import DateFormatter  # Formatting dates on axis
import matplotlib.dates as mdates           # Date locators and formatters
from matplotlib.lines import Line2D         # Custom legend handles
from matplotlib.colors import LogNorm       # Optional: log scale normalization for heatmaps

import seaborn as sns                       # Statistical data visualization built on matplotlib
from wordcloud import WordCloud             # Generating word-cloud visualizations

# === Graph Analysis ===
import networkx as nx                       # Create and analyze graph structures (e.g., topic similarity graphs)

# === Machine Learning / NLP ===
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer  
                                            # Text → TF-IDF or term-frequency matrices
from sklearn.cluster import KMeans          # K-Means clustering algorithm
from sklearn.cluster import DBSCAN          # DBSCAN for density-based clustering
from sentence_transformers import SentenceTransformer, util  
                                            # Pretrained transformer embeddings + similarity utilities

# %%
# 🛠️ SQL Server connection parameters
server = 'NIKITA-PC'                     # the database server name
database = 'CyberNewsBot'                # the target database name
driver = 'ODBC Driver 17 for SQL Server' # the ODBC driver to use for the connection

# Build the SQLAlchemy connection string
connection_string = (
    f"mssql+pyodbc://@{server}/{database}"              # protocol + server + database
    f"?driver={driver.replace(' ', '+')}&Trusted_Connection=yes"
)
engine = create_engine(connection_string)  # create the SQLAlchemy engine for executing queries

# %% [markdown]
# #### <div dir="rtl">חלק 2: פונקציית `load_posted_news`</div>
# <div dir="rtl">
# שגרה בתהליך ה־ETL לקריאה וסינון מאמרים שעברו בהצלחה (`PostedNews`):
#
# 1. קריאה של הקובץ `posted_news_ud.json` לתוך DataFrame.
# 2. המרת העמודה `keywords` מרשימה למחרוזת מופרדת בפסיקים.
# 3. ביצוע שאילתת SQL לשליפת כל הערכים של `text_hash` שכבר קיימים.
# 4. סינון רשומות שכבר נטענו ויישום של `drop_duplicates` על `text_hash`.
# </div>

# %%
def load_posted_news(engine, json_path: str = "posted_news_ud.json") -> pd.DataFrame:
    df = pd.read_json(json_path) 
    # Read the JSON file into a pandas DataFrame
    
    if 'keywords' in df.columns: 
        df['keywords'] = df['keywords'].str.join(',')
        
    existing = pd.read_sql("SELECT text_hash FROM PostedNews", con=engine) 
    #Query the database for all text_hash values already in PostedNews
    
    mask = ~df['text_hash'].isin(existing['text_hash'])  
    #Create a boolean mask marking only rows whose text_hash is not yet in the database
    
    new_df = df.loc[mask]  
    #Apply the mask to filter the DataFrame
    
    new_df = new_df.drop_duplicates(subset=['text_hash']).copy()  
    #Remove any duplicate rows based on text_hash, then make a copy to avoid warnings
    
    return new_df
    # Return the cleaned DataFrame of new articles

# %% [markdown]
# #### <div dir="rtl">חלק 3: פונקציית `load_skipped_news`</div>
# <div dir="rtl"> שגרה בתהליך ה־ETL לקריאה וסינון מאמרים שדולגו (`SkippedNews`):
#
# 1. טעינת הקובץ `skipped_news_ud.json` כ־dict בפייתון והמרה ל־DataFrame.
# 2. הסרת העמודה המיותרת `date`.
# 3. ביצוע שאילתת SQL לשליפת כל הערכים של `text_hash` שכבר קיימים.
# 4. סינון רשומות שכבר נטענו ויישום `drop_duplicates` על `text_hash`.
# </div>

# %%
def load_skipped_news(engine, json_path: str = "skipped_news_ud.json") -> pd.DataFrame:
    with open(json_path, encoding='utf-8') as f:
        data = json.load(f)  
        # Load the JSON file into a Python dict

    df = pd.DataFrame(list(data.values())) 
    # Convert the dict values into a pandas DataFrame

    if 'date' in df.columns: # If there is an unused 'date' column, drop it
        df = df.drop(columns=['date'])

    existing = pd.read_sql("SELECT text_hash FROM SkippedNews", con=engine) 
    # Query the database for all text_hash values already in SkippedNews

    mask = ~df['text_hash'].isin(existing['text_hash']) 
    # Create a boolean mask for records not yet in the database

    new_df = df.loc[mask].drop_duplicates(subset=['text_hash']).copy()  
    # Filter the DataFrame by the mask and drop any duplicates by text_hash

    return new_df  
    # Return the cleaned DataFrame of new skipped entries

# %% [markdown]
# #### <div dir="rtl">חלק 4: פונקציית `main` לביצוע ה־ETL</div>
# <div dir="rtl">
#
# 1. קריאה לפונקציה `load_posted_news` וכתיבת הרשומות החדשות לטבלה `PostedNews`.
# 2. קריאה לפונקציה `load_skipped_news` וכתיבת הרשומות החדשות לטבלה `SkippedNews`.
# 3. הדפסת הודעות סטטוס והצגת 5 כותרות מאמרים לדוגמה מכל טבלה.
# </div>

# %%
def main():
    # ——— Step 1: Load PostedNews ———
    posted = load_posted_news(engine)  
    # Call the ETL function to get new posted articles

    if not posted.empty:  
        # If there are new articles, append them to the PostedNews table
        posted.to_sql(
            "PostedNews",                 
            con=engine,
            if_exists="append",            
            index=False,                   
            chunksize=1000,                
            dtype={                        
                'published_date': Date(),  
                'published_time': Time(),  
                'keywords': NVARCHAR(length=None)  
            }
        )
        print(f"✅ Loaded {len(posted)} new articles to PostedNews.")
        print("Sample titles loaded into PostedNews:")
        for title in posted['title'].head(5):  
            print(f"  - {title}")
    else:
        print("ℹ️ No new articles to load into PostedNews.")

    # ——— Step 2: Load SkippedNews ———
    skipped = load_skipped_news(engine)  
    # Call the ETL function to get new skipped articles

    if not skipped.empty:  
        # If there are new entries, append them to the SkippedNews table
        skipped.to_sql(
            "SkippedNews",                 
            con=engine,
            if_exists="append",
            index=False,
            chunksize=1000,
            dtype={
                'published_date': Date(),  
                'published_time': Time(),  
                'reason': NVARCHAR(length=300)  
            }
        )
        print(f"✅ Loaded {len(skipped)} new entries to SkippedNews.")
        print("Sample titles loaded into SkippedNews:")
        for title in skipped['title'].head(5):
            print(f"  - {title}")
    else:
        print("ℹ️ No new entries to load into SkippedNews.")

if __name__ == "__main__":
    main()  
    # When this script is executed directly, run the main() function
# Out:
# ✅ Loaded 4829 new articles to PostedNews.
# Sample titles loaded into PostedNews:
#   - R Street report examines open-source AI cyber risks, calls for federal guidelines
#   - CISA, DHS, INL host LSU to strengthen cyber defense training across critical infrastructure sector
#   - Cowbell introduces Prime One Tech in the UK to support cyber and PI needs of growing tech sector
#   - FBI: Cybercrime cost victims 'staggering' $16.6B last year - The Register
#   - Cowbell Launches New Professional Indemnity Offering for UK Tech Firms
# ✅ Loaded 1513 new entries to SkippedNews.
# Sample titles loaded into SkippedNews:
#   - पुण्यात बनावट कॉल सेंटरचा भंडाफोड, 100 पेक्षा अधिक जण ताब्यात | Pune Cyber Crime - YouTube
#   - Undocumented Communication Devices Found in Chinese Solar Tech Spark U.S. Security Concerns
#   - Tech coalition to push for faster US foreign cybersecurity aid - Digital Watch Observatory
#   - Cyber support center set up in Jaipur to strengthen cybersecurity - MSN
#   - IT Security News Daily Summary 2025-05-24

# %% [markdown]
# # <div dir="rtl">🔹שלב 2: ניתוח נתונים חוקר (EDA) ויצירת ויזואליזציות מרכזיות</div>
# <div dir="rtl">
# בשלב זה נטען ונבחן את טבלאות PostedNews ו-SkippedNews, נבצע הנדסת תכונות על תאריכים/זמנים ומילות מפתח, ניצור תרשים דונאט של מילות המפתח המובילות, ונפיק חמש ויזואליזציות עיקריות—מגמות הצלחה לעומת כישלון, שיעורי צמיחה יומיים, התפלגות סיבות לכישלון, השוואות בין פרסומים ודילוגים לפי מדינה, ומפת חום של כישלונות לפי סיבה ותאריך.
# </div>

# %% [markdown]
# #### <div dir="rtl">חלק 1: שליפת נתונים ובדיקה ראשונית</div>
# <div dir="rtl">
# בקטע זה נטען את הטבלאות `PostedNews` ו-`SkippedNews` ל־DataFrames של pandas ונבצע בדיקות חקירה בסיסיות: ממדים, ספירת כפילויות, מידע על עמודות, ערכים חסרים, סטטיסטיקות תיאוריות, ספירת ערכים ייחודיים, דגימות אקראיות והתפלגות תאריכים.
# </div>
#
# ##### <div dir="rtl"> <strong>ניתוח הפלט:</strong></div>
# <div dir="rtl">
# ניתן לראות שטבלת ה־PostedNews מכילה 4829 רשומות, ללא כפילויות (title, url, text_hash), ומעט מאוד ערכים חסרים או כפולים במידע התיאורי של המאמרים. מספר ימי הפרסום הוא 47, כאשר יש פיזור טוב בין תאריכים שונים, וכמות המאמרים המקסימלית ביום מסוים היא 190. רוב הערכים בטבלה הם ייחודיים (לדוג' כותרות, קישורים, מזהי טקסט). בטבלת ה־SkippedNews, יש 1513 רשומות, ולמרות שאין כפילויות ב־text_hash, נמצאו לא מעט כפילויות לפי title ו־url, מה שמצביע על ניסיונות חוזרים לפרסם תכנים דומים או חזרתיות בסיקור. רוב ערכי הסיבה לדחייה הם “Duplicate by summary hash”, כלומר מנגנון הזיהוי פועל כראוי. הנתונים עצמם נקיים, אין ערכים חסרים, והם מסודרים היטב לבדיקה וניתוח ראשוני. התפלגות התאריכים מראה שיש ימים עמוסים בפרסומים וימים דלילים יחסית, גם ב־Posted וגם ב־Skipped, דבר שמאפשר לחקור מגמות עונתיות או תגובות לאירועים בולטים. </div>

# %%
# Retrieving tables from SQL into DataFrames
posted_df = pd.read_sql("SELECT * FROM PostedNews ORDER BY ID", con=engine)  
skipped_df = pd.read_sql("SELECT * FROM SkippedNews ORDER BY ID", con=engine)

# --- PostedNews basic checks ---
print("=== POSTED DF SHAPE ===", posted_df.shape)             
# How many rows and columns

print("=== POSTED DUPLICATES ===", posted_df.duplicated().sum())  
# Total duplicate rows

print("Duplicates by title:", posted_df['title'].duplicated().sum())      
print("Duplicates by url:", posted_df['url'].duplicated().sum())          
print("Duplicates by text_hash:", posted_df['text_hash'].duplicated().sum())  
# Duplicate counts for key columns

print("=== POSTED COLUMNS ===", posted_df.columns.tolist())  
# List of column names

print("=== POSTED NULLS ===\n", posted_df.isnull().sum())  
# Count of missing values per column

print("=== POSTED INFO ===")  
posted_df.info()  
# DataFrame info: dtype, non-null counts

print("=== POSTED DESCRIBE ===\n", posted_df.describe(include='all'))  
# Descriptive statistics for all columns

print("\nNumber of unique values for each column:")
print(posted_df.nunique())  
# Unique value counts per column

print("\nRandom sample from posted_df:")
print(posted_df.sample(5))  
# Display 5 random rows

print("\nSort articles by date:")
print(posted_df['published_date'].value_counts().sort_index())  
# Frequency of articles per date, sorted chronologically

# --- SkippedNews basic checks ---
print("=== SKIPPED DF SHAPE ===", skipped_df.shape)             
print("=== SKIPPED DUPLICATES ===", skipped_df.duplicated().sum())
print("Duplicates by title:", skipped_df['title'].duplicated().sum())
print("Duplicates by url:", skipped_df['url'].duplicated().sum())
print("Duplicates by text_hash:", skipped_df['text_hash'].duplicated().sum())

print("=== SKIPPED COLUMNS ===", skipped_df.columns.tolist())
print("=== SKIPPED NULLS ===\n", skipped_df.isnull().sum())
print("=== SKIPPED INFO ===")
skipped_df.info()

print("=== SKIPPED DESCRIBE ===\n", skipped_df.describe(include='all'))
print("\nNumber of unique values for each column:")
print(skipped_df.nunique())

print("\nRandom sample from skipped_df:")
print(skipped_df.sample(5))

print("\nSort articles by date:")
print(skipped_df['published_date'].value_counts().sort_index())
# Out:
# === POSTED DF SHAPE === (4829, 10)
# === POSTED DUPLICATES === 0
# Duplicates by title: 0
# Duplicates by url: 0
# Duplicates by text_hash: 0
# === POSTED COLUMNS === ['ID', 'title', 'url', 'text_hash', 'summary', 'source', 'published_date', 'published_time', 'rss_source', 'keywords']
# === POSTED NULLS ===
#  ID                0
# title             0
# url               0
# text_hash         0
# summary           0
# source            0
# published_date    0
# published_time    0
# rss_source        0
# keywords          0
# dtype: int64
# === POSTED INFO ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4829 entries, 0 to 4828
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              4829 non-null   int64
#  1   title           4829 non-null   object
#  2   url             4829 non-null   object
#  3   text_hash       4829 non-null   object
#  4   summary         4829 non-null   object
#  5   source          4829 non-null   object
#  6   published_date  4829 non-null   object
#  7   published_time  4829 non-null   object
#  8   rss_source      4829 non-null   object
#  9   keywords        4829 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 377.4+ KB
# === POSTED DESCRIBE ===
#                   ID                                              title  \
# count   4829.000000                                               4829
# unique          NaN                                               4829
# top             NaN  White House urges Keir Starmer to block Chines...
# freq            NaN                                                  1
# mean    2415.000000                                                NaN
# std     1394.156555                                                NaN
# min        1.000000                                                NaN
# 25%     1208.000000                                                NaN
# 50%     2415.000000                                                NaN
# 75%     3622.000000                                                NaN
# max     4829.000000                                                NaN
#
#                                                       url  \
# count                                                4829
# unique                                               4829
# top     https://uk.news.yahoo.com/white-house-urges-ke...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                 text_hash  \
# count                                                4829
# unique                                               4829
# top     df8d2075bd7258dbf2f6a647d8736384aae638da93d565...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                   summary              source  \
# count                                                4829                4829
# unique                                               4810                1244
# top     The full content of this article is only avail...  industrialcyber.co
# freq                                                    5                  94
# mean                                                  NaN                 NaN
# std                                                   NaN                 NaN
# min                                                   NaN                 NaN
# 25%                                                   NaN                 NaN
# 50%                                                   NaN                 NaN
# 75%                                                   NaN                 NaN
# max                                                   NaN                 NaN
#
#        published_date published_time     rss_source  \
# count            4829           4829           4829
# unique             47           4649              6
# top        2025-04-28       13:02:12  United States
# freq              190              4           2624
# mean              NaN            NaN            NaN
# std               NaN            NaN            NaN
# min               NaN            NaN            NaN
# 25%               NaN            NaN            NaN
# 50%               NaN            NaN            NaN
# 75%               NaN            NaN            NaN
# max               NaN            NaN            NaN
#
#                                      keywords
# count                                    4829
# unique                                   4659
# top     groceries,returning,shops,after,cyber
# freq                                        8
# mean                                      NaN
# std                                       NaN
# min                                       NaN
# 25%                                       NaN
# 50%                                       NaN
# 75%                                       NaN
# max                                       NaN
#
# Number of unique values for each column:
# ID                4829
# title             4829
# url               4829
# text_hash         4829
# summary           4810
# source            1244
# published_date      47
# published_time    4649
# rss_source           6
# keywords          4659
# dtype: int64
#
# Random sample from posted_df:
#         ID                                              title  \
# 3550  3551  Death on A5 shows need to upgrade road, says E...
# 2855  2856  CISA has a new Number 2: Madhu Gottumukkala - ...
# 1448  1449  Hackers & Headlines: Defending your Newsroom f...
# 3150  3151  Midwestern telco Cellcom confirms cyber incide...
# 1981  1982  Insurer Coalition: Costs From Business Email C...
#
#                                                     url  \
# 3550  https://www.itv.com/news/utv/2025-05-26/road-d...
# 2855  https://www.theregister.com/2025/05/19/cisa_de...
# 1448  https://wnanews.com/event/hackers-headlines-de...
# 3150  https://therecord.media/midwestern-cellcom-tel...
# 1981  https://www.insurancejournal.com/news/national...
#
#                                               text_hash  \
# 3550  ee83565d1286b784dd6d2f24d9ffe7e532c1f5f9316fcc...
# 2855  5018192cc925cd80196066f100d2d88268e7faa88cc6a6...
# 1448  59b9dea9123459d47f617b88ab6a09f11aecf4c07e767d...
# 3150  0cf013b3f2cb867ed7a20ef1a6c6ac535c16517c661067...
# 1981  1641ba301234c10f867a7bd9acb8349337f679be87bc66...
#
#                                                 summary  \
# 3550  Death on A5 shows need to upgrade road, says E...
# 2855  Madhu Gottumukkala is the new deputy director ...
# 1448  Hackers & Headlines: Defending your Newsroom f...
# 3150  Midwestern telco Cellcom confirms cyber incide...
# 1981  Insurer Coalition: Costs From Business Email C...
#
#                         source published_date published_time     rss_source  \
# 3550               www.itv.com     2025-05-26       17:47:56        England
# 2855       www.theregister.com     2025-05-20       05:01:37  United States
# 1448               wnanews.com     2025-05-06       20:11:01  United States
# 3150           therecord.media     2025-05-22       13:36:41  United States
# 1981  www.insurancejournal.com     2025-05-12       16:30:22  United States
#
#                                                keywords
# 3550            there,currently,legal,challenge,against
# 2855  cybersecurity,infrastructure,security,agency,m...
# 1448                insights,cyber,threats,affect,press
# 3150            cellcom,brighid,riordan,company,dealing
# 1981                 about,claims,handled,cyber,insurer
#
# Sort articles by date:
# published_date
# 2025-04-23     40
# 2025-04-24    132
# 2025-04-25    118
# 2025-04-26     83
# 2025-04-27     59
# 2025-04-28    190
# 2025-04-29    145
# 2025-04-30    129
# 2025-05-01     99
# 2025-05-02    110
# 2025-05-03     66
# 2025-05-04     63
# 2025-05-05    117
# 2025-05-06    125
# 2025-05-07     64
# 2025-05-08     95
# 2025-05-09    108
# 2025-05-10     81
# 2025-05-11     58
# 2025-05-12    133
# 2025-05-13    130
# 2025-05-14    136
# 2025-05-15    153
# 2025-05-16    122
# 2025-05-17     49
# 2025-05-18     73
# 2025-05-19    150
# 2025-05-20    156
# 2025-05-21    127
# 2025-05-22    123
# 2025-05-23    147
# 2025-05-24     47
# 2025-05-25     60
# 2025-05-26     59
# 2025-05-27    155
# 2025-05-28    135
# 2025-05-29    125
# 2025-05-30    116
# 2025-05-31     51
# 2025-06-01     67
# 2025-06-02    144
# 2025-06-03     86
# 2025-06-04     72
# 2025-06-05    131
# 2025-06-06    129
# 2025-06-07     47
# 2025-06-08     24
# Name: count, dtype: int64
# === SKIPPED DF SHAPE === (1513, 11)
# === SKIPPED DUPLICATES === 0
# Duplicates by title: 177
# Duplicates by url: 183
# Duplicates by text_hash: 0
# === SKIPPED COLUMNS === ['ID', 'title', 'url', 'text_hash', 'summary', 'source', 'published_date', 'published_time', 'rss_source', 'reason', 'fail_count']
# === SKIPPED NULLS ===
#  ID                0
# title             0
# url               0
# text_hash         0
# summary           0
# source            0
# published_date    0
# published_time    0
# rss_source        0
# reason            0
# fail_count        0
# dtype: int64
# === SKIPPED INFO ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1513 entries, 0 to 1512
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              1513 non-null   int64
#  1   title           1513 non-null   object
#  2   url             1513 non-null   object
#  3   text_hash       1513 non-null   object
#  4   summary         1513 non-null   object
#  5   source          1513 non-null   object
#  6   published_date  1513 non-null   object
#  7   published_time  1513 non-null   object
#  8   rss_source      1513 non-null   object
#  9   reason          1513 non-null   object
#  10  fail_count      1513 non-null   int64
# dtypes: int64(2), object(9)
# memory usage: 130.2+ KB
# === SKIPPED DESCRIBE ===
#                   ID                                              title  \
# count   1513.000000                                               1513
# unique          NaN                                               1336
# top             NaN  Chinese mainland police pursue 20 suspects inv...
# freq            NaN                                                  5
# mean     757.000000                                                NaN
# std      436.909792                                                NaN
# min        1.000000                                                NaN
# 25%      379.000000                                                NaN
# 50%      757.000000                                                NaN
# 75%     1135.000000                                                NaN
# max     1513.000000                                                NaN
#
#                                   url  \
# count                            1513
# unique                           1330
# top     https://www.youtube.com/watch
# freq                               29
# mean                              NaN
# std                               NaN
# min                               NaN
# 25%                               NaN
# 50%                               NaN
# 75%                               NaN
# max                               NaN
#
#                                                 text_hash  \
# count                                                1513
# unique                                               1513
# top     4793e7fdfda4325820f9a01367f4276669f797fffc6bf6...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                   summary       source  \
# count                                                1513         1513
# unique                                               1513          566
# top     Marks and Spencer is also working with experts...  www.msn.com
# freq                                                    1           55
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#        published_date published_time     rss_source  \
# count            1513           1513           1513
# unique             15           1385              6
# top        2025-05-27       21:24:05  United States
# freq              159              3            854
# mean              NaN            NaN            NaN
# std               NaN            NaN            NaN
# min               NaN            NaN            NaN
# 25%               NaN            NaN            NaN
# 50%               NaN            NaN            NaN
# 75%               NaN            NaN            NaN
# max               NaN            NaN            NaN
#
#                            reason   fail_count
# count                        1513  1513.000000
# unique                          5          NaN
# top     Duplicate by summary hash          NaN
# freq                          961          NaN
# mean                          NaN     1.545274
# std                           NaN     0.520193
# min                           NaN     1.000000
# 25%                           NaN     1.000000
# 50%                           NaN     2.000000
# 75%                           NaN     2.000000
# max                           NaN     3.000000
#
# Number of unique values for each column:
# ID                1513
# title             1336
# url               1330
# text_hash         1513
# summary           1513
# source             566
# published_date      15
# published_time    1385
# rss_source           6
# reason               5
# fail_count           3
# dtype: int64
#
# Random sample from skipped_df:
#         ID                                              title  \
# 872    873  M&S cyber-attack stoking fears across British ...
# 491    492  Cybersecurity Stocks: Keep An Eye On Palo Alto...
# 1510  1511        IEEE Standards & Projects for Cybersecurity
# 937    938  Advisory: Pakistanis told to change social med...
# 596    597  Cyber Security Market Industry Report 2025 - R...
#
#                                                     url  \
# 872   https://www.digit.fyi/ms-cyber-attack-stoking-...
# 491   https://www.investors.com/research/ibd-industr...
# 1510  https://standards.ieee.org/initiatives/cyberse...
# 937   http://www.msn.com/en-gb/money/technology/advi...
# 596   https://www.businesswire.com/news/home/2025053...
#
#                                               text_hash  \
# 872   daa4d250ce0f64bc9b08a918c690e9f9ab89ade9db8578...
# 491   a82cfaed7df3e537408ec2be603c5015b634387925786f...
# 1510  d9dcf73d9208091b22c2ea01978fecd3cee33f11e3b799...
# 937   e52a930f4abf300e1f44716ee6a5169bd8ccd98aaa1ab7...
# 596   14318f3d5cdbf9a0655c4e4d0e64f6b703b10261cd10d8...
#
#                                                 summary                source  \
# 872   British businesses fear hackers could complete...         www.digit.fyi
# 491   Cybersecurity stocks, like Palo Alto Networks ...     www.investors.com
# 1510  Featured Projects and Standards · IEEE 1547.3™...    standards.ieee.org
# 937   UAE Cyber Security Council urges immediate act...           www.msn.com
# 596   Cybersecurity has become an essential part of ...  www.businesswire.com
#
#      published_date published_time     rss_source  \
# 872      2025-06-02       11:30:33        England
# 491      2025-05-29       18:38:42  United States
# 1510     2025-06-08       06:35:36  United States
# 937      2025-06-02       16:45:48        England
# 596      2025-05-30       14:12:29  United States
#
#                                   reason  fail_count
# 872            Duplicate by summary hash           2
# 491   Article text is empty or too short           1
# 1510                  Duplicate by title           1
# 937   Article text is empty or too short           2
# 596                   Duplicate by title           2
#
# Sort articles by date:
# published_date
# 2025-05-25     57
# 2025-05-26     58
# 2025-05-27    159
# 2025-05-28    153
# 2025-05-29    138
# 2025-05-30    129
# 2025-05-31     76
# 2025-06-01     65
# 2025-06-02    151
# 2025-06-03     76
# 2025-06-04     70
# 2025-06-05    152
# 2025-06-06    128
# 2025-06-07     65
# 2025-06-08     36
# Name: count, dtype: int64

# %% [markdown]
# #### <div dir="rtl">חלק 2: המרת תאריכים ושעות והנדסת תכונות</div>
# <div dir="rtl">
# בקטע זה אנו מבצעים סטנדרטיזציה לעמודות התאריך/שעה ויוצרים תכונות עזר (`day_of_week`, `hour`) עבור שני ה־DataFrames.
# </div>

# %%
# Parse published_date as datetime, coercing invalid formats to NaT
posted_df['published_date'] = pd.to_datetime(
    posted_df['published_date'], errors='coerce'
)

# Parse published_time as time objects, then extract .hour
posted_df['published_time'] = pd.to_datetime(
    posted_df['published_time'], format='%H:%M:%S', errors='coerce'
).dt.time

# Repeat for skipped_df
skipped_df['published_date'] = pd.to_datetime(
    skipped_df['published_date'], errors='coerce'
)
skipped_df['published_time'] = pd.to_datetime(
    skipped_df['published_time'], format='%H:%M:%S', errors='coerce'
).dt.time

# Feature: day of week
posted_df['day_of_week'] = posted_df['published_date'].dt.day_name()
skipped_df['day_of_week'] = skipped_df['published_date'].dt.day_name()

# Feature: hour of day
posted_df['hour'] = pd.to_datetime(posted_df['published_time'], errors='coerce').dt.hour
skipped_df['hour'] = pd.to_datetime(skipped_df['published_time'], errors='coerce').dt.hour

# Aggregate counts per date for comparison
daily_sent = posted_df['published_date'].value_counts().sort_index()
daily_skipped = skipped_df['published_date'].value_counts().sort_index()

# Combine into a single DataFrame for side-by-side comparison
comparison_df = pd.DataFrame({'Sent': daily_sent,'Skipped': daily_skipped}).fillna(0).astype(int)

print("\nDaily breakdown of articles sent vs. failed:")
print(comparison_df)
# Out:
# Daily breakdown of articles sent vs. failed:
#                 Sent  Skipped
# published_date
# 2025-04-23        40        0
# 2025-04-24       132        0
# 2025-04-25       118        0
# 2025-04-26        83        0
# 2025-04-27        59        0
# 2025-04-28       190        0
# 2025-04-29       145        0
# 2025-04-30       129        0
# 2025-05-01        99        0
# 2025-05-02       110        0
# 2025-05-03        66        0
# 2025-05-04        63        0
# 2025-05-05       117        0
# 2025-05-06       125        0
# 2025-05-07        64        0
# 2025-05-08        95        0
# 2025-05-09       108        0
# 2025-05-10        81        0
# 2025-05-11        58        0
# 2025-05-12       133        0
# 2025-05-13       130        0
# 2025-05-14       136        0
# 2025-05-15       153        0
# 2025-05-16       122        0
# 2025-05-17        49        0
# 2025-05-18        73        0
# 2025-05-19       150        0
# 2025-05-20       156        0
# 2025-05-21       127        0
# 2025-05-22       123        0
# 2025-05-23       147        0
# 2025-05-24        47        0
# 2025-05-25        60       57
# 2025-05-26        59       58
# 2025-05-27       155      159
# 2025-05-28       135      153
# 2025-05-29       125      138
# 2025-05-30       116      129
# 2025-05-31        51       76
# 2025-06-01        67       65
# 2025-06-02       144      151
# 2025-06-03        86       76
# 2025-06-04        72       70
# 2025-06-05       131      152
# 2025-06-06       129      128
# 2025-06-07        47       65
# 2025-06-08        24       36

# %% [markdown]
# #### <div dir="rtl">חלק 3: ניקוי והפקת מילות מפתח</div>
# <div dir="rtl">
# הסרת מילות קישור נפוצות מרשימת מילות המפתח הגולמית של כל מאמר ליצירת עמודה cleaned_keywords, חישוב ממוצע מילות המפתח לכל מאמר, וזיהוי 10 מילות המפתח הנפוצות ביותר בכל המאמרים שפורסמו.
# </div>

# %%
#Stopwords and keyword cleaning
#Create a cleaned_keywords column

stopwords = {
    "the", "a", "an", "and", "or", "with", "by", "from", "after", "against", "company", "their", "its", "on",
    "for", "in", "of", "to", "is", "are", "was", "as", "this", "that", "these", "those", "about", "into",
    "platform", "portal", "manage", "known", "primarily", "better", "current", "systems"
}

def clean_keywords(keyword_str):
    return [
        word.strip().lower()
        for word in str(keyword_str).split(',')
        if word.strip().lower() and word.strip().lower() not in stopwords
    ]

posted_df['cleaned_keywords'] = posted_df['keywords'].apply(clean_keywords)

#Average keywords per article
avg_keywords_per_article = posted_df['cleaned_keywords'].apply(len).mean()
print(f"Average number of keywords per article: {avg_keywords_per_article:.2f}")


def get_top_keywords(df, column: str, top_n: int = 10) -> pd.DataFrame:
    return ( df[column].explode().value_counts().nlargest(top_n).rename_axis('keyword').reset_index(name='count').astype({'count': int}))

# Usage
top10 = get_top_keywords(posted_df, 'cleaned_keywords', top_n=10)
print("Top 10 Keywords:")
print(top10.to_string(index=False))
# Out:
# Average number of keywords per article: 4.89
# Top 10 Keywords:
#       keyword  count
#         cyber   1981
#      security    819
# cybersecurity    596
#        attack    237
#   information    144
#      national    142
#         marks    136
#       spencer    126
#       threats    125
#       attacks    103

# %% [markdown]
# #### <div dir="rtl">🔸תרשים דונאט של מילות המפתח המובילות</div>
# <div dir="rtl">
# בקטע זה אנו ממחישים את שיעור התדירות היחסי של 8 מילות המפתח המובילות.
# </div>

# %%
def plot_top_keywords_pie(df, top_n=8,
                          figsize=(8, 8),
                          cmap_name="flare",
                          donut=True):

    # 1) Aggregate & sort
    top = (get_top_keywords(df, 'cleaned_keywords', top_n).sort_values('count', ascending=False).reset_index(drop=True))

    labels = top['keyword']
    sizes  = top['count']
    total  = sizes.sum()

    # 2) Build colour list out of the chosen colormap
    cmap   = plt.colormaps.get_cmap(cmap_name)
    colors = cmap(np.linspace(0, 1, len(labels)))

    # 3) Create the figure & axes (equal aspect keeps the pie round)
    fig, ax = plt.subplots(figsize=figsize, subplot_kw=dict(aspect="equal"))

    # 4) Draw the wedges
    wedgeprops = dict(width=0.45) if donut else None   # width<1 → donut
    
    wedges, texts, autotexts = ax.pie(
        
        sizes,
        colors=colors,
        startangle=180,              # rotate so the largest slice starts at 140°
        autopct=lambda pct:
            f"{pct:.1f}%\n({int(pct/100.*total):,})",  # show % + absolute
        pctdistance=0.8 if donut else 0.6,             # text position
        textprops=dict(color="white", weight="bold",fontsize=10),
        wedgeprops=wedgeprops
    )

    # 5) Legend on the right
    ax.legend(wedges, labels, title="Keyword",loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))

    # 6) Title
    ax.set_title(f"Top {top_n} Keywords – Share of Mentions", weight="bold")
    return fig, ax

fig, ax = plot_top_keywords_pie(posted_df, top_n=8)
plt.show()

# %% [markdown]
# #### <div dir="rtl">חלק 4: סדרות זמן ואגרגציות (5 גרפים)</div>
# <div dir="rtl">
# סטטיסטיקות יומיות וברמת מדינה של פרסום וכישלון מאמרים.
# </div>
# <div dir="rtl">
#
# - חישוב סך כל המאמרים שפורסמו בכל תאריך (`articles_per_day`) על ידי קיבוץ הנתונים בעמודת `published_date` וספירת מספר הרשומות בכל יום.
# - חישוב סך כל המאמרים שנכשלו בכל תאריך (`failures_per_day`) על ידי קיבוץ הנתונים בטבלת הכישלונות בעמודת `published_date` וספירה.
# - חישוב מספר המאמרים שפורסמו לפי מדינה (`posted_per_country`) ומספר המאמרים שנדחו לפי מדינה (`skipped_per_country`) באמצעות ספירת הערכים בעמודת `rss_source` בכל אחד מה-DataFrames.
# - חישוב מספר הכישלונות לפי סיבה ותאריך (`failures_by_reason_date`) על ידי קיבוץ לפי עמודות `published_date` ו-`reason`, וספירה. הפלט הוא טבלה בה כל עמודה מייצגת סיבת כישלון וכל שורה מייצגת תאריך.
# </div>

# %%
#Total articles published by date
articles_per_day = posted_df.groupby('published_date').size()
#Total failed articles by date
failures_per_day = skipped_df.groupby('published_date').size()

#Total articles published And not published by country
posted_per_country = posted_df['rss_source'].value_counts().rename('Published')
skipped_per_country = skipped_df['rss_source'].value_counts().rename('Skipped')

#Failure reasons by date
failures_by_reason_date = skipped_df.groupby(['published_date', 'reason']).size().unstack(fill_value=0)

# %% [markdown]
# #### <div dir="rtl">🔸גרף 1: גרף השוואתי משולב של הצלחות מול כישלונות</div>
# <div dir="rtl">
# הקוד מאחד את נתוני ההצלחות והכישלונות, ובונה תרשים קווי המציג לכל יום את מספר המאמרים שפורסמו לעומת מספר המאמרים שנכשלו. הגרף ממחיש את המגמות לאורך זמן, כולל כותרות, תוויות וסימון כל תאריך בציר ה-X.
# </div>

# %%
# Step 1: Combine published & failed counts into one DataFrame
combined_df = pd.concat([
    articles_per_day.rename('Published'),
    failures_per_day.rename('Failed')
], axis=1).fillna(0)

# Reset index to turn the dates into a column
ts_df = combined_df.reset_index().rename(columns={'index': 'published_date'})

# Step 2: Create the line plot
fig, ax = plt.subplots(figsize=(14, 7))

sns.lineplot(
    data=ts_df,
    x='published_date',
    y='Published',
    marker='o',
    label='Published',
    ax=ax
)
sns.lineplot(
    data=ts_df,
    x='published_date',
    y='Failed',
    marker='o',
    label='Failed',
    ax=ax
)

# Step 3: Force the x-axis to cover the entire date range (including the last date)
ax.set_xlim(
    ts_df['published_date'].min(),
    ts_df['published_date'].max()
)

# Step 4: Show every single date tick on the x-axis
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))   # one tick per day
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))     # format as YYYY-MM-DD
fig.autofmt_xdate(rotation=45)                              # rotate labels for readability

# Step 5: Final touches
ax.set_title('Published vs Failed Articles Per Day')
ax.set_xlabel('Date')
ax.set_ylabel('Number of Articles')
ax.grid(True)
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### <div dir="rtl">🔸גרף 2: שיעור הצמיחה היומי במאמרים שפורסמו</div>
# <div dir="rtl">
# הקוד מחשב את שיעור השינוי היומי (באחוזים) במספר המאמרים שפורסמו, יוצר ממוצע נע ל־7 ימים, ומציג גרף קווי עם שטח בצבע ירוק כאשר השינוי חיובי ואדום כאשר שלילי. בנוסף, הקוד מסמן קו אנכי עבור יום הפרסום האחרון, כולל תווית. הגרף מסייע לזהות מגמות יומיות, תנודתיות ומגמות ארוכות טווח בפרסום מאמרים.
# </div>

# %%
# Step 1: Prepare DataFrame
# — compute daily % change and reset index for plotting
growth = articles_per_day.pct_change().fillna(0) * 100
df_growth = growth.reset_index().rename(columns={
    'published_date': 'date',
    0: 'pct_change'
})

# Step 2: Calculate 7-day rolling average
# — for each day, average that day + previous 6 days (min_periods=1 allows early days)
df_growth['rolling'] = df_growth['pct_change'].rolling(window=7, min_periods=1)\
    .mean()

# Step 3: Identify the last publish date
# — pick the last index where at least one article was published
last_pub_date = articles_per_day[articles_per_day > 0].last_valid_index()

# Step 4: Create the plot
fig, ax = plt.subplots(figsize=(12, 6))

# 4a) Plot daily % change line
sns.lineplot(data=df_growth, x='date', y='pct_change',color='tab:blue', label='Daily % Change', ax=ax
)

# 4b) Fill areas: green when positive, red when negative
ax.fill_between(
    df_growth['date'], df_growth['pct_change'], 0,
    where=(df_growth['pct_change'] >= 0),
    interpolate=True, color='tab:green', alpha=0.3
)

ax.fill_between(
    df_growth['date'], df_growth['pct_change'], 0,
    where=(df_growth['pct_change'] < 0),
    interpolate=True, color='tab:red', alpha=0.3
)

# 4c) Plot the 7-day moving average
sns.lineplot(
    data=df_growth, x='date', y='rolling',
    color='black', linewidth=2, label='7-day MA', ax=ax
)

# Step 5: Mark the last publish date
# — vertical dashed line
ax.axvline(
    last_pub_date, color='purple', linestyle='--', linewidth=2,
    label=f'Last publish: {last_pub_date.strftime("%Y-%m-%d")}'
)
# — text annotation next to the line
y_max = ax.get_ylim()[1]
ax.text(
    last_pub_date, y_max * 0.9,
    last_pub_date.strftime('%Y-%m-%d'),
    rotation=90, color='purple', va='top', ha='right'
)

# Step 6: Final formatting
ax.set_title('Daily Growth Rate (%) in Published Articles – Area & 7-day MA')
ax.set_xlabel('Date')
ax.set_ylabel('% Change')
ax.legend()
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
fig.autofmt_xdate(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### <div dir="rtl">🔸גרף 3: התפלגות אחוזית של סיבות הכישלון</div>
# <div dir="rtl">
# הקוד מחשב את אחוז כל סיבת כישלון מסך כל הכישלונות, ויוצר תרשים עמודות אופקי המציג את התפלגות הסיבות. כל עמודה מראה את האחוז והכמות עבור כל סיבה.
# </div>

# %%
reason_counts = (
    skipped_df['reason']
    .value_counts()                       # count occurrences of each reason
    .rename_axis('reason')                # name the index “reason”
    .reset_index(name='count')            # turn into DataFrame with columns ['reason','count']
)

total = reason_counts['count'].sum()     # sum of all failure counts
reason_counts['pct'] = (                # add a new column 'pct'
    reason_counts['count'] / total * 100  # percentage share of each reason
)

sns.set_theme(style="whitegrid")          # set a clean background with grid lines
fig, ax = plt.subplots(figsize=(10, 6))  # create figure and axes, size in inches

sns.barplot(
    data=reason_counts,                   # supply the DataFrame
    y='reason',                           # plot reasons along the y-axis (horizontal bars)
    x='pct',                              # length of bars = percentage values
    hue='reason',                         # use the 'reason' column to map colors
    palette=sns.light_palette("seagreen", n_colors=len(reason_counts), reverse=True),
    dodge=False,                          # do not separate bars by hue categories
    ax=ax                                 # draw on our axes
)

if ax.get_legend() is not None:
    ax.get_legend().remove()

# Annotate each bar with “xx.x% (nnn)” to show both percentage and raw count
for i, row in reason_counts.iterrows():
    ax.text(
        row['pct'] + 0.5,                 # x-coordinate: slightly to the right of bar end
        i,                                 # y-coordinate: same as bar index
        f"{row['pct']:.1f}% ({row['count']})",  # text label
        va='center'                       # vertical alignment: center on the bar
    )

# Final formatting: titles and axis labels
ax.set_title('Failure Reasons Distribution (by Percentage)', fontsize=14, pad=12)
ax.set_xlabel('Percentage of Failures', fontsize=12)
ax.set_ylabel('Reason', fontsize=12)
plt.tight_layout()                       # adjust subplots to fit in the figure area
plt.show()                               # display the plot

# %% [markdown]
# #### <div dir="rtl">🔸גרף 4: מאמרים שפורסמו לעומת מאמרים שדולגו לפי מדינה</div>
# <div dir="rtl">
# הקוד מאחד נתונים של מאמרים שפורסמו ושנדחו לפי מדינה, ממיר את הנתונים לפורמט ארוך, ומציג גרף עמודות אופקי המשווה בין כמות המאמרים שפורסמו לכמות המאמרים שדולגו בכל מדינה. כל עמודה מייצגת מדינה, עם פירוט לפי סטטוס (פורסם/נדחה).
# </div>

# %%
# Join the two series → wide table
country_wide = pd.concat([posted_per_country, skipped_per_country], axis=1).fillna(0).astype(int)

# Keep only countries that have at least one article (either status)
country_wide = country_wide.loc[country_wide.sum(axis=1) > 0]

# Convert to “long” format for seaborn
country_long = (
    country_wide
    .sort_values('Published', ascending=False)      # order by Published
    .reset_index(names='country')                  # move index to column
    .melt(id_vars='country',                       # -> columns: country | status | count
          var_name='status',
          value_name='count')
)

# Plot grouped horizontal bars
sns.set_theme(style="whitegrid")
fig, ax = plt.subplots(figsize=(12, 6))

# Custom palette: Published = blue, Skipped = red
palette = {'Published': 'tab:blue', 'Skipped': 'tab:red'}

sns.barplot(
    data=country_long,
    y='country', x='count',
    hue='status',            # now hue distinguishes Published vs Skipped
    palette=palette,
    dodge=True,              # side-by-side bars (horizontal grouping)
    ax=ax
)

# Annotate each bar (skip bars with width == 0)
for p in ax.patches:
    width = p.get_width()
    if width == 0:       # לא להדפיס טקסט על בר “ריק”
        continue
    ypos = p.get_y() + p.get_height() / 2
    ax.text(
        width + country_long['count'].max() * 0.01,
        ypos,
        f'{int(width):,}',
        va='center'
    )

ax.set_title('Published vs Skipped Articles by Country', fontsize=15, pad=12)
ax.set_xlabel('Number of Articles', fontsize=12)
ax.set_ylabel('Country', fontsize=12)
ax.legend(title='Status', frameon=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### <div dir="rtl">🔸גרף 5: מפת חום – סיבת כישלון לפי תאריך</div>
# <div dir="rtl">
# הקוד יוצר טבלת שכיחויות של כישלונות לפי סיבה ותאריך, ומציג מפת חום (heatmap) שממחישה כמה מאמרים נכשלו בכל סיבה בכל יום. כל תא במפה מייצג את מספר הכישלונות לאותה סיבה בתאריך מסוים.
# </div>

# %%
order = failures_by_reason_date.sum(axis=0).sort_values(ascending=False).index
heat_data = failures_by_reason_date[order]
heat_data.index = heat_data.index.strftime('%d-%m-%Y')

fig, ax = plt.subplots(figsize=(14, 7))
sns.heatmap(
    heat_data,
    cmap="OrRd",
    annot=True, fmt='d',
    linewidths=.5, linecolor='white',
    yticklabels=heat_data.index,            # index כבר מחרוזות
    cbar_kws={"label": "Number of Failures"},
    ax=ax
)

ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # <div dir="rtl">🔹שלב 3: זיהוי כפילויות וזרימת פרסום לפי שעה</div>
# <div dir="rtl">
# בשלב זה מאתרים את המאמרים הכפולים ביותר—לפי כותרת, תקציר (hash) וכתובת URL—ולאחר מכן בונים וממחישים את זרימת הפרסומים לעומת כפילויות לפי שעות במהלך השבוע האחרון באמצעות גרף פיזור עם גודל בועות.
# </div>

# %% [markdown]
# #### <div dir="rtl">חלק 1: זיהוי הכפילויות המובילות לפי כותרת, תקציר (Hash) ו־URL</div>
# <div dir="rtl">
# בקטע זה מחשבים ומציגים את המאמרים הכפולים ביותר בשלוש קטגוריות—לפי כותרת, לפי תקציר (hash), ולפי כתובת URL—כדי להבליט את מקורות הכפילות השכיחים ביותר.
# </div>

# %%
# PARAMETERS
MIN_DUP   = 1
TOP_N     = 5
TITLE_REASON = 'Duplicate by title'
HASH_REASON  = 'Duplicate by summary hash'
URL_REASON  = 'Duplicate by url'

def show_top_dupes(df_posted: pd.DataFrame,
                   df_skipped: pd.DataFrame,
                   reason: str,
                   count_col_out: str,
                   key_col: str,
                   min_dup: int = 2,
                   top_n: int = 10) -> pd.DataFrame:
  
    # count how many skipped per key
    counts = (df_skipped[df_skipped['reason'] == reason].groupby(key_col).size())
    total_dup_in_skipped = counts.sum()

    # map counts back to posted dataframe
    df_posted[count_col_out] = (
        df_posted[key_col].map(counts).fillna(0).astype(int)
    )

    # filter only rows with at least min_dup duplicates
    noisy = df_posted[df_posted[count_col_out] >= min_dup]

    # add percentage column
    noisy = (noisy[['title', count_col_out]].assign(
            perc_of_reason=lambda x: (x[count_col_out] / total_dup_in_skipped * 100).round(1))
             
        .sort_values(count_col_out, ascending=False)
        .head(top_n)
    )

    
    # 5️⃣ pretty print
    print(f"\n► {reason} — Top {top_n} (≥{min_dup} duplicates)")
    print(noisy.to_string(index=False))

    return noisy

# RUN for title duplicates
top_title_dupes = show_top_dupes(
    posted_df.copy(),
    skipped_df,
    reason=TITLE_REASON,
    count_col_out='dup_titles',
    key_col='title',
    min_dup=MIN_DUP,
    top_n=TOP_N
)

# RUN for summary-hash duplicates
top_hash_dupes = show_top_dupes(
    posted_df.copy(),
    skipped_df,
    reason=HASH_REASON,
    count_col_out='dup_hashes',
    key_col='text_hash',
    min_dup=MIN_DUP,
    top_n=TOP_N
)

# RUN for summary-url duplicates
top_hash_dupes = show_top_dupes(
    posted_df.copy(),
    skipped_df,
    reason=URL_REASON,
    count_col_out='dup_url',
    key_col='url',
    min_dup=MIN_DUP,
    top_n=TOP_N
)
# Out:
# ► Duplicate by title — Top 5 (≥1 duplicates)
#                                                                                        title  dup_titles  perc_of_reason
# Chinese mainland police pursue 20 suspects involved in cyber attacks initiated by Taiwan ...           4             1.7
#  INE Security Alert: $16.6 Billion in Cyber Losses Underscore Critical Need for Advanced ...           3             1.3
#                                 NEOM McLaren Formula E Team & Trend Micro Innovation History           3             1.3
#      Marks & Spencer secures raft of former Homebase sites for new food stores | Retail Week           2             0.9
#            Governor Abbott in San Antonio expected to sign bill creating Texas Cyber Command           2             0.9
#
# ► Duplicate by summary hash — Top 5 (≥1 duplicates)
#                                                                                  title  dup_hashes  perc_of_reason
#                        Bet with Monero: Privacy & Speed in Betting | Value The Markets           1             0.1
#                                              Why Securing NHIs Reduces Your Cyber Risk           1             0.1
#                 Cyber Incident Delays Teacher Pay at South Carolina District - GovTech           1             0.1
#       Federal CIO wants problem solvers, not problem describers - Federal News Network           1             0.1
# SentinelOne vs. Fortinet: Which Cybersecurity Stock is the Better Buy? - Yahoo Finance           1             0.1
#
# ► Duplicate by url — Top 5 (≥1 duplicates)
#                                                                                          title  dup_url  perc_of_reason
#                              Marks & Spencer appoints Thinus Keeve to new retail director role        1            20.0
#                           How Are SMEs Reacting to the Rise of AI and Increased Cyber Threats?        1            20.0
#                                                             Cyber Career Pathways Tool | NICCS        1            20.0
# Nonprofit cyber group raises questions over private sector involvement in cyber deterrence ...        1            20.0
#            CISA at a crossroads amid workforce cuts, pause partnerships - Federal News Network        1            20.0

# %% [markdown]
# #### <div dir="rtl">🔸גרף: זרימת פרסום וכפילויות לפי שעה</div>
# <div dir="rtl">
# בקטע זה בונים טבלאות שעתיות של מאמרים שפורסמו ודולגו (כפולים) במהלך השבוע האחרון, וממחישים את הזרימה שלהם באמצעות גרף פיזור עם גודל בועה.
# </div>
#
# <div dir="rtl">
# הקוד בונה טבלאות שעתיות למאמרים שפורסמו ולמאמרים שזוהו ככפולים במהלך השבוע האחרון, וממחיש אותם בגרף פיזור שבו גודל הבועה מייצג את כמות המאמרים בכל שעה וסיבה. הצבעים מייצגים את סטטוס הפרסום (פורסם או סוג כפילות), והגרף מסייע לנתח דפוסי פרסום וכפילויות לאורך שעות היממה.
# </div>

# %%
warnings.filterwarnings('ignore', category=FutureWarning, module='pandas')

def build_hourly_tables(
        posted_df : pd.DataFrame,
        skipped_df: pd.DataFrame,
        window_days : int = 7,
        scale       : int = 6
    ) -> tuple[pd.DataFrame, pd.DataFrame, pd.DataFrame]:
   
    for df in (posted_df, skipped_df):
        df['pub_hour'] = ( pd.to_datetime(
                df['published_date'].astype(str) + ' ' +df['published_time'].astype(str),errors='coerce').dt.floor('h'))

    end = max(posted_df['pub_hour'].max(), skipped_df['pub_hour'].max())
    start = end - pd.Timedelta(days=7)
    
    pw = posted_df.loc[(posted_df['pub_hour'] >= start) & (posted_df['pub_hour'] <= end)].copy()

    duplicate_reasons = [
        'Duplicate by title',
        'Duplicate by summary hash',
        'Duplicate by url']

    sw = (skipped_df.loc[(skipped_df['pub_hour'] >= start) & (skipped_df['pub_hour'] <= end)]
        .loc[skipped_df['reason'].isin(duplicate_reasons)].copy())

    posted_hourly = (pw.groupby('pub_hour').size().reset_index(name='count').assign(reason='Published'))

    skipped_hourly = (sw.groupby(['pub_hour', 'reason']).size().reset_index(name='count'))

    for gdf in (posted_hourly, skipped_hourly):
        gdf['bubble_size'] = np.log1p(gdf['count']) * scale

    plot_df = pd.concat([posted_hourly, skipped_hourly], ignore_index=True) \
               [['pub_hour', 'count', 'reason', 'bubble_size']]

    
    return plot_df, posted_hourly, skipped_hourly

def plot_hourly_flow(
        plot_df       : pd.DataFrame,
        posted_hourly : pd.DataFrame,
        skipped_hourly: pd.DataFrame) -> None:

    class DateFmt(mdates.ConciseDateFormatter):
        def format_tick(self, x, _):
            return mdates.num2date(x).strftime('%d.%m') 
            
    class HourFmt(mdates.ConciseDateFormatter):
        def format_tick(self, x, _):
            return mdates.num2date(x).strftime('%H:%M') 

    major = mdates.DayLocator()
    minor = mdates.HourLocator(byhour=[0, 6, 12, 18]) 

    palette = {
        'Published'                 : 'grey',
        'Duplicate by title'        : 'tab:blue',
        'Duplicate by summary hash' : 'tab:orange',
        'Duplicate by url'          : 'tab:green'}

    sns.set_theme(style="whitegrid", font_scale=1.2) 
    fig, ax = plt.subplots(figsize=(20, 6), dpi=120) 

    
    sns.scatterplot(
        data=plot_df,
        x='pub_hour', y='count',
        hue='reason', size='bubble_size',
        palette=palette, sizes=(16, 450),
        edgecolor='k', linewidth=.35, alpha=.68, ax=ax)

    
    for _, r in posted_hourly[posted_hourly['count'] >= 5].iterrows():
        ax.text(r['pub_hour'], 
                r['count'] + .25, 
                r['count'],ha='center',
                fontsize=7, color='dimgray') 
        
    for _, r in skipped_hourly[skipped_hourly['count'] >= 5].iterrows(): 
        ax.text(r['pub_hour'], r['count'] + .25, r['count'],ha='center', fontsize=7)

    
    ax.xaxis.set_major_locator(major)
    ax.xaxis.set_minor_locator(minor)
    ax.xaxis.set_major_formatter(DateFmt(major)) 
    ax.xaxis.set_minor_formatter(HourFmt(minor)) 

    ax.grid(which='major', axis='x', linestyle='-', linewidth=2, color='lightgrey') 
    ax.grid(which='minor', axis='x', linestyle=':', linewidth=1.45, color='gainsboro')

    ax.tick_params(axis='x', which='major', labelsize=12) 
    ax.tick_params(axis='x', which='minor', labelsize=8)
    plt.setp(ax.get_xticklabels(), rotation=0, ha='center') 

    sample_n = [2, 6, 12]
    size_handles = [
        Line2D([0], [0], marker='o', linestyle='', 
               markersize=np.log1p(n) * 1.5,
               markerfacecolor='grey', markeredgecolor='k',
               label=f'{n} articles') for n in sample_n]

    status_handles = [ Line2D([0], [0], marker='o', markersize=8, linestyle='', markerfacecolor=palette[key], markeredgecolor='k', label=label)
        for key, label in [
            ('Published',                 'Published'),
            ('Duplicate by title',        'Duplicate – Title'),
            ('Duplicate by summary hash', 'Duplicate – Hash'),
            ('Duplicate by url',          'Duplicate – URL')] ]

    ax.legend(handles=status_handles + size_handles,
              title='Status  &  Bubble size\n(log count scale)',
              frameon=False, 
              loc='upper left')

    ax.set_title('Last-Week Flow – Published vs Duplicate Articles', fontsize=16, pad=12)
    ax.set_xlabel('Date ↓   /   6-hour slots →', fontsize=12)
    ax.set_ylabel('Number of Articles', fontsize=12)
    plt.tight_layout()
    plt.show()

plot_df, posted_hourly, skipped_hourly = build_hourly_tables(posted_df, skipped_df)
plot_hourly_flow(plot_df, posted_hourly, skipped_hourly)

# %% [markdown]
# # <div dir="rtl">🔹שלב 4: אשכול נושאים וניתוח מגמות</div>
# <div dir="rtl">
# בשלב זה ממירים את המאמרים לוקטורים, מאשכלים אותם לפי דמיון סמנטי, מחשבים סיכומים ודוגמאות לכל אשכול, מציגים את מגמות הפרסום של כל נושא, ומנתחים את הפיצול בין מאמרים ייחודיים לכפולים.
# </div>

# %% [markdown]
# #### <div dir="rtl">חלק 1: שילוב כותרת ותקציר, טעינת מודל שפה והמרה לווקטורים</div>
# <div dir="rtl">
# בקטע זה משלבים את הכותרת והתקציר של כל מאמר לשדה טקסט אחד (`super_text`), טוענים את מודל השפה paraphrase-MiniLM-L6-v2, וממירים את כל שורות הטקסט לוקטורים מספריים (embedding) עבור אשכול נושאים בהמשך.
# </div>

# %%
from sklearn.cluster import DBSCAN

posted_df['super_text'] = posted_df['title'].astype(str) + " " + posted_df['summary'].astype(str)
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# Convert each article into a numerical embedding vector representing its content
embeddings = model.encode(posted_df['super_text'].tolist(), show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/151 [00:00<?, ?it/s]

# %% [markdown]
# #### <div dir="rtl">חלק 2: אשכול באמצעות DBSCAN וספירת נושאים וכפילויות</div>
# <div dir="rtl">בקטע זה מתבצע אשכול (Clustering) של מאמרים לפי דמיון סמנטי באמצעות האלגוריתם DBSCAN. האלגוריתם פועל על הווקטורים המייצגים את תוכן המאמרים (embeddings) ומסווג כל מאמר לקבוצת נושא (cluster), או משייך אותו לרעש (noise) אם אינו דומה מספיק לשום קבוצה.
#
#  ##### <div dir="rtl">הפרמטרים המשמשים לאשכול:</div>
# - <b>eps=0.19</b>: רדיוס החיפוש – כמה דומים צריכים להיות שני מאמרים כדי להיחשב כשכנים (ככל שהערך קטן יותר, האשכולות יהיו "צפופים" יותר).
# - <b>min_samples=2</b>: מינימום שכנים ליצירת אשכול – נדרש לפחות שני מאמרים דומים כדי להיחשב כקבוצה.
# - <b>metric='cosine'</b>: מדד דמיון קוסינוס – משמש למדידת מרחק בין וקטורי embedding (רלוונטי ל-NLP).
#  <div dir="rtl">
# כל מאמר מקבל מזהה נושא (`topic_id`) לפי האשכול שבו שובץ, או ‎–1 אם הוא סווג כרעש (מאמר ייחודי שלא דומה לאחרים).
# לבסוף, הקוד סופר את מספר האשכולות (נושאים) האמיתיים, את מספר המאמרים שסווגו כרעש, ומציג סיכום של התוצאות.
# תהליך זה מסייע לאתר קבוצות של מאמרים דומים מבחינה סמנטית, וגם לזהות מאמרים חריגים שאין להם דומים.
# </div>

# %%
# 2. Apply DBSCAN on the embeddings
# eps: radius around each point – how close points need to be to be considered neighbors
# min_samples=2: minimum number of neighbors required to form a cluster
# metric='cosine': measure distance between embeddings using cosine distance
db = DBSCAN(eps=0.19, min_samples=2, metric='cosine')
labels = db.fit_predict(embeddings)  # labels – each article’s cluster ID (integer), or -1 if it’s noise
posted_df['topic_id'] = labels       # add a new column to the DataFrame with cluster IDs (or -1 for noise)

# 3. Count clusters and noise
n_clusters = len(set(labels)) - (1 if -1 in labels else 0)  # compute the number of real clusters (exclude -1 for noise)
n_noise = (labels == -1).sum()                             # count how many articles weren’t assigned to any cluster
print(f"\nDBSCAN: Found {n_clusters} topics (clusters) and {n_noise} noise articles (not assigned to any topic).\n")  # summary printout
# Out:
# DBSCAN: Found 310 topics (clusters) and 3793 noise articles (not assigned to any topic).

# %% [markdown]
# #### <div dir="rtl">חלק 3: חישוב גודל נושא וסינון אשכולות מובילים</div>
# <div dir="rtl">
# בקטע זה לכל מאמר מחושב כמה מאמרים נוספים משתייכים לאותו נושא (topic_id), למעט מאמרים שמסווגים כרעש (noise). לאחר מכן, מסננים החוצה את המאמרים שלא שובצו לשום נושא, ובוחרים את חמשת האשכולות הגדולים ביותר – כלומר, נושאים שבהם יש לפחות חמישה מאמרים בכל אשכול.
#
# <div dir="rtl"> הסבר על התהליך:
#
# - עבור כל מאמר שמסווג לאשכול, הקוד מחשב כמה "עמיתים" (peers) יש לו – כלומר, כמה מאמרים נוספים חולקים את אותו topic_id.
# - מאמרים שמסומנים כרעש (topic_id == -1) מקבלים ערך 0.
# - יוצרים DataFrame חדש שכולל רק את המאמרים ששויכו לאשכול (ומסננים החוצה את כל ה-noise).
# - מחשבים את גודל כל אשכול (כלומר, כמה מאמרים בכל נושא).
# - בוחרים את חמשת האשכולות הגדולים ביותר מתוך אלה שבהם יש לפחות חמישה מאמרים.
# תהליך זה עוזר למקד את הניתוח בנושאים הבולטים והמשמעותיים, תוך התעלמות ממאמרים בודדים או נושאים קטנים.
# </div>

# %%
# Compute similar_articles and similar_count based on topic_id
def get_similar_articles(idx, topic_id, labels):
    if topic_id == -1:
        return []
    # Find all articles with the same topic_id (excluding itself)
    indices = np.where(labels == topic_id)[0]  # Find all indices of articles in the same cluster
    # Return the indices of similar articles (excluding itself)
    return [int(i) for i in indices if i != idx]

posted_df['similar_count'] = (
    posted_df.groupby('topic_id')['topic_id']        # For each topic, get the series of topic IDs
             .transform('size')                      # Repeat cluster size for each row
             .sub(1)                                 # Exclude the article itself
             .where(posted_df['topic_id'] != -1, 0)  # Assign 0 for noise articles
)

# Create DataFrame of only significant topics (e.g., with 5 or more articles)
topic_df = posted_df[posted_df['topic_id'] != -1].copy()  # Filter to include only clustered articles (exclude noise)
topic_df['topic_id'] = topic_df['topic_id'].astype(int)   # Convert cluster IDs to integers
topic_sizes = topic_df['topic_id'].value_counts()        # Count how many articles are in each cluster
# Select the top 5 largest clusters (at least 5 articles each)
large_topics = topic_sizes[topic_sizes >= 5].index.tolist()
print(f"Selected the top 5 strongest topics (out of {sum(topic_sizes >= 5)} topics with at least 5 articles)")
# Out:
# Selected the top 5 strongest topics (out of 43 topics with at least 5 articles)

# %% [markdown]
# #### <div dir="rtl">חלק 4: איגוד ותצוגת סיכום עבור נושאים חזקים</div>
# <div dir="rtl">
# בקטע זה מאגדים את חמשת האשכולות הגדולים ביותר כדי לחשב עבור כל נושא סטטיסטיקות מרכזיות: מספר מאמרים, תאריך פרסום ראשון ואחרון, המדינה/מקור העיקרי, ורשימת מזהי המאמרים. לאחר מכן מציגים דוגמאות של מאמרים מתוך כל נושא – כולל תאריך, מקור, וחלק מכותרת המאמר.
# <div dir="rtl"> הסבר התהליך:
#
# - בוחרים את כל המאמרים ששויכו לאחד מחמשת הנושאים הגדולים.
# - מבצעים קיבוץ לפי מזהה נושא (topic_id) ומחשבים לכל נושא: גודל, טווח תאריכים, מקור עיקרי ורשימת מזהי מאמרים.
# - בונים טבלת סיכום של כל הנושאים החזקים.
# - מדפיסים לכל נושא דוגמאות של מאמרים עם תאריך, מקור וחלק מהכותרת.
# השלב הזה עוזר לזהות במהירות נושאים דומיננטיים, להבין את הפיזור שלהם ולסקור מאמרים מייצגים לכל נושא.
# </div>

# %%
# --- Build an aggregated summary for the “strong” topics only ----------------
agg_df = (
    # Keep rows whose topic_id is in the list large_topics
    topic_df.loc[topic_df['topic_id'].isin(large_topics)]
            # Group by topic_id – everything that follows runs per-topic
            .groupby('topic_id')
            # Aggregate several statistics for each topic
            .agg(
                num_articles=('topic_id', 'size'),                 # how many articles in the topic
                first_date   =('published_date', 'min'),          # earliest publication date
                last_date    =('published_date', 'max'),          # latest  publication date
                main_country =('rss_source',
                               lambda x: x.mode()[0]),            # most frequent country (rss_source)
                article_ids  =('topic_id',
                               lambda x: x.index.tolist())         # list of article indices belonging to the topic
            )
            # Put topic_id back as a normal column instead of an index
            .reset_index()
)

# --- Final summary table: keep only the rows whose topic_id appears in large_topics
#     (strictly redundant here because agg_df already contains only those IDs,
#      but it is a safe guard if large_topics is modified later).
topic_summary = agg_df.loc[agg_df['topic_id'].isin(large_topics)]

# %%
print("\n=== Examples of topics with at least 5 articles ===")
for topic in large_topics: 
    subset = topic_df[topic_df['topic_id'] == topic].sort_values('published_date')
    print(f"\n Topic ID: {topic} - {len(subset)} articles")
    for _, row in subset.iterrows():
        print(f"  - {row['published_date'].date()} | {row['rss_source']} | {row['title'][:95]}.")
# Out:
# === Examples of topics with at least 5 articles ===
#
#  Topic ID: 7 - 87 articles
#   - 2025-04-24 | United States | M&S takes systems offline as 'cyber incident' lingers - The Register.
#   - 2025-04-24 | United States | M&S struggles to get on top of 'cyber incident' - The Irish Times.
#   - 2025-04-24 | United States | M&S systems remain offline days after cyber incident - Computer Weekly.
#   - 2025-04-25 | United States | M&S cyberattack: online orders suspended after week of disruption - The Times.
#   - 2025-04-25 | England | M&S suspends online orders after cyber incident - Sharecast.com.
#   - 2025-04-25 | England | M&S halts all online orders amid ongoing disruption caused by cyber attack - ITVX.
#   - 2025-04-25 | United States | M&S halts online orders as 'cyber incident' gets worse - The Register.
#   - 2025-04-25 | England | M&S pauses online and app orders following cyber attack - The Herald.
#   - 2025-04-25 | England | Marks and Spencer pauses online orders after reported hacking incident | Shropshire Star.
#   - 2025-04-25 | England | M&S stops taking online orders as cyber attack rages on - City AM.
#   - 2025-04-25 | England | M&S pauses online orders - Drapers.
#   - 2025-04-25 | England | M&S shoppers facing continued disruption days after cyber attack hit systems - STV News.
#   - 2025-04-25 | England | M&S pauses all online orders after cyber attack - The Irish News.
#   - 2025-04-25 | England | Marks & Spencer halts online orders following cyber incident - TheIndustry.fashion.
#   - 2025-04-25 | England | M&S: Marks and Spencer pauses online orders after cyber attack - The National.
#   - 2025-04-25 | United States | Marks & Spencer pauses online orders as firm struggles with cyber-attack fallout.
#   - 2025-04-25 | England | M&S shoppers face disruption days after cyber attack hit contactless payments and click and col.
#   - 2025-04-25 | England | M&S Still Suffering Cyber Incident Consequences, Processes Offline | SC Media UK.
#   - 2025-04-25 | England | M&S still struggling to get back to normal after cyber attack - Tech Digest.
#   - 2025-04-25 | England | M&S Halts Online Orders Following Cyber Attack - Share Talk.
#   - 2025-04-26 | England | M&S suspends online orders as cyber attack causes further chaos for shoppers.
#   - 2025-04-26 | England | Marks and Spencer freezes online orders after cyber attack - Yahoo News UK.
#   - 2025-04-28 | England | Everything we know about the M&S cyber attack that halted online orders.
#   - 2025-04-28 | United States | M&S cyber crisis wipes almost €800m off retailer's valuation - The Irish Times.
#   - 2025-04-28 | United States | M&S cyber-attack: when will orders be back, and is my data at risk? | Marks & Spencer.
#   - 2025-04-28 | England | Marks & Spencer (M&S) is currently grappling with a significant cyberattack for fourth day.
#   - 2025-04-28 | England | M&S blocks remote workers and halts online sales following suspected ransomware breach.
#   - 2025-04-28 | England | M&S still unable to accept online orders more than a week after cyber attack | ITV News.
#   - 2025-05-03 | United States | Clothing shortages, food waste and millions lost each day: inside the M&S cyber-attack chaos.
#   - 2025-05-13 | England | M&S Admits Customers' Personal Data Was Accessed During Cyber Attack - KamCity.
#   - 2025-05-13 | England | M&S admits customer data was stolen by hackers in cyber attack - Yahoo News UK.
#   - 2025-05-13 | United States | M&S admits cybercrooks made off with customer info - The Register.
#   - 2025-05-13 | England | Chart: Marks & Spencer cyber-attack could have £40m weekly sales impact.
#   - 2025-05-13 | United States | U.K. Retail Giant M&S Says Customer Data Was Compromised in Cyberattack.
#   - 2025-05-13 | United States | M&S says hackers gained access to customer data in April cyberattack | Cybersecurity Dive.
#   - 2025-05-13 | England | M&S confirms customer data breach after cyber-attack - Digit.fyi.
#   - 2025-05-13 | England | Marks and Spencer says customer data stolen as part of ongoing cyber attack.
#   - 2025-05-13 | England | M&S customers had personal data stolen in cyber attack - YourMoney.com.
#   - 2025-05-13 | England | M&S reveals hackers accessed customer data | ITV News.
#   - 2025-05-13 | United States | UK's M&S says customer data was taken in cyber attack - Yahoo Finance.
#   - 2025-05-13 | United States | Marks & Spencer notifies Irish data watchdog after cyber attack - The Irish Times.
#   - 2025-05-13 | England | Marks & Spencer reveals customer data taken by hackers after cyber attack | Express & Star.
#   - 2025-05-13 | England | M&S reveals hackers accessed customer's data in cyber attack - Latest From ITV News.
#   - 2025-05-13 | England | What we know as M&S hackers steal customer data - Yahoo News UK.
#   - 2025-05-13 | England | Customer data stolen in cyber attack, M&S confirms - STV News.
#   - 2025-05-13 | England | Personal data stolen in Marks & Spencer cyber-attack - Holyrood.
#   - 2025-05-13 | England | M&S admits hackers stole personal customer data in cyber attack - City AM.
#   - 2025-05-13 | England | M&S admits customer data was stolen in cyber attack - Tech Digest.
#   - 2025-05-13 | United States | M&S says some personal data was taken in cyber-attack | Marks & Spencer | The Guardian.
#   - 2025-05-13 | England | M&S discloses customer data breach following cyber attack - Share Talk.
#   - 2025-05-13 | England | Marks & Spencer reveals customer data taken by hackers after cyber attack - Yahoo Finance.
#   - 2025-05-14 | England | Chart: Marks & Spencer cyber attack could have £40m weekly sales impact.
#   - 2025-05-15 | England | Hackers that hit M&S and other UK shops are now attacking US stores, Google says.
#   - 2025-05-16 | England | Marks & Spencer cyber attack likely cost retail giant millions daily - Yahoo Finance.
#   - 2025-05-16 | England | M&S expected to shed light on cost of cyber attack hit | Express & Star.
#   - 2025-05-18 | England | Shareholders eye more details on M&S cyber attack impact - City AM.
#   - 2025-05-18 | United States | M&S to reveal cyber attack impact after customers left unable to shop - LancsLive.
#   - 2025-05-18 | England | M&S to break silence on 'devastating' impact of cyber attack - Yahoo News UK.
#   - 2025-05-19 | United States | M&S' slow recovery from cyberattack puts it at risk of lasting damage - Yahoo Finance.
#   - 2025-05-19 | England | M&S attack exposes long term cyber fallout for UK firms - City AM.
#   - 2025-05-21 | United States | M&S cyberattack to wipe out nearly one-third of annual profits - CNBC.
#   - 2025-05-21 | United States | M&S cyber attack disruption likely to last until July - Computer Weekly.
#   - 2025-05-21 | England | Slow recovery 'appropriate' to ensure M&S is secure after cyber attack – experts.
#   - 2025-05-21 | England | M&S cyber attack could cost £300 million, disruptions expected until July - Tech Digest.
#   - 2025-05-21 | England | Slow recovery 'appropriate' to ensure M&S is secure after cyber attack - Cumnock Chronicle.
#   - 2025-05-21 | United States | M&S warns April cyberattack will cut $400 million from profits | Cybersecurity Dive.
#   - 2025-05-21 | England | Security matters as hackers hit retailers where it hurts | Portfolio Adviser.
#   - 2025-05-21 | England | M&S Reveals Cyber Attack Will Cost £300m With Impact Continuing For Weeks - KamCity.
#   - 2025-05-21 | United States | Marks & Spencer Says Cyber Attack to Cost Business £300 Million - Bloomberg.
#   - 2025-05-21 | England | M&S says cyber attack disruption will cost £300m 'and will last to July' - The Irish News.
#   - 2025-05-21 | England | Marks & Spencer in 'best financial health for 30 years' but cyber attack cost bites deep.
#   - 2025-05-21 | England | M&S cyber-attack expected to wipe put £300 million from profits - London Loves Business.
#   - 2025-05-21 | England | M&S warns of £300m profit hit from cyber-attack after strong results - Drapers.
#   - 2025-05-21 | England | M&S cyber attack to cost £300m with disruption until July - Retail Systems.
#   - 2025-05-21 | England | M&S says cyber-attack disruption to last until July and is likely to cost £300 million.
#   - 2025-05-21 | England | M&S expected to reveal impact of cyber attack disruption - Dunfermline Press.
#   - 2025-05-21 | England | Marks & Spencer says cyber attack disruption set to cost £300m and last to July | The Herald.
#   - 2025-05-21 | England | Marks and Spencer says cyber attack likely to cost £300m and last till July | ITV News.
#   - 2025-05-21 | United States | Cyber-attack cost Marks & Spencer £300m in lost sales, company results reveal.
#   - 2025-05-21 | England | M&S expected to reveal impact of cyber attack disruption - Express & Star.
#   - 2025-05-21 | England | M&S cyber attack "a moment in time" as retailer focuses on recovery - InternetRetailing.
#   - 2025-05-22 | England | M&S website down as retailer endures lengthy recovery from cyber attack.
#   - 2025-05-22 | United States | Will cyber-attack threaten M&S's hard-won return to fashion relevance? | Marks & Spencer.
#   - 2025-05-22 | England | M&S website down as fallout from cyber attack continues - The Herald.
#   - 2025-05-22 | England | M&S website down as retailer endures lengthy recovery from cyber attack | Express & Star.
#   - 2025-05-22 | England | M&S website back up for browsing after being taken down overnight - The Irish News.
#   - 2025-05-23 | England | Comment | Inside the ongoing M&S ransomware crisis - Digit.fyi.
#
#  Topic ID: 82 - 23 articles
#   - 2025-05-01 | United States | Harrods becomes latest UK retailer to fall victim to cyber attack | Computer Weekly.
#   - 2025-05-01 | England | Harrods becomes latest retailer struck by cyberattack attempts - Latest From ITV News.
#   - 2025-05-01 | United States | Harrods the next UK retailer targeted in a cyberattack - Bleeping Computer.
#   - 2025-05-01 | England | Harrods targeted by cyber attack as it becomes latest retail victim - Yahoo News UK.
#   - 2025-05-01 | England | Harrods becomes latest retail victim of cyber attackers - TheIndustry.fashion.
#   - 2025-05-01 | England | Luxury department store Harrods latest retail victim of a cyber attack.
#   - 2025-05-01 | England | Harrods is latest British retailer to be hit by cyber attack - FashionNetwork United Kingdom.
#   - 2025-05-01 | England | Harrods hit by latest cyber attack against retailers - Channel 4.
#   - 2025-05-01 | United States | Harrods is latest retailer to be hit by cyber-attack - The Guardian.
#   - 2025-05-01 | England | Harrods hit by cyber attack amid wave of retailer hacking incidents - Yahoo Finance.
#   - 2025-05-02 | United States | Harrods becomes latest UK retailer to face cyber threat as M&S' struggles persist.
#   - 2025-05-02 | United States | Three massive UK retailers have been hit by cyber attacks this week – so what's going on?.
#   - 2025-05-02 | England | Harrods targeted in third cyber-attack on a major UK retailer - Digit.fyi.
#   - 2025-05-02 | England | Harrods targeted in cyber attack as retailers warned of Bank Holiday threat.
#   - 2025-05-02 | United States | Harrods confirms cyberattack, GCHQ's cybersec folk step in - The Register.
#   - 2025-05-02 | England | Harrods third British retailer hit by cyber incident in two weeks - Retail Systems.
#   - 2025-05-02 | England | Harrods hit in cyber spree as experts warn of 'coordinated campaign' - City AM.
#   - 2025-05-02 | United States | Harrods hit by cyber attack as UK retailers battle threats | IT Pro - ITPro.
#   - 2025-05-02 | England | Harrods Hit in Cyber Attack Wave Targeting Retailers - CEO Today.
#   - 2025-05-02 | England | Harrods Latest Victim in Wave of Retail Cyber Attacks - International Supermarket News.
#   - 2025-05-02 | England | Harrods becomes latest retailer struck by cyber attack attempts | STV News.
#   - 2025-05-02 | England | Harrods becomes latest retail victim of cyber attack, report claims - Tech Digest.
#   - 2025-05-03 | England | Harrods and Co-op join M&S as cyber attack targets - YourMoney.com.
#
#  Topic ID: 251 - 18 articles
#   - 2025-05-26 | United States | Adidas: Customer Contact Info Stolen in Data Breach | PYMNTS.com.
#   - 2025-05-27 | United States | Adidas loses customer data in latest cyber attack - Thred Website.
#   - 2025-05-27 | England | Adidas becomes the latest firm to be hit with a cyberattack - London Loves Business.
#   - 2025-05-27 | England | Adidas hit by cyber-attack as customer data stolen - Drapers.
#   - 2025-05-27 | England | Hackers steal Adidas customer data in cyber attack - Yahoo Finance.
#   - 2025-05-27 | England | Adidas warns cyber attack stole customer data - Yahoo News UK.
#   - 2025-05-27 | England | Adidas hit in yet another UK retail data breach - City AM.
#   - 2025-05-27 | England | Adidas customer data stolen in latest retail cyber attack - Tech Digest.
#   - 2025-05-27 | United States | Adidas Confirms Cyber Attack and Data Breach - WWD.
#   - 2025-05-27 | Germany | Data leak at Adidas: contact data tapped via third-party providers - It-daily.net.
#   - 2025-05-27 | Germany | Data leak: criminals steal Adidas customer data - Heise.
#   - 2025-05-27 | England | Adidas discloses cyber-attack, customer data compromised - Digit.fyi.
#   - 2025-05-27 | England | Adidas customer data stolen as it becomes latest retailer to be hit by cyber attack.
#   - 2025-05-28 | United States | Adidas confirms customer data was accessed during cyber attack - Computer Weekly.
#   - 2025-05-28 | United States | Adidas Confirms Cyber Attack, Customer Data Stolen - Hackread.
#   - 2025-05-28 | England | Adidas latest to suffer data breach through third-party provider - Retail Systems.
#   - 2025-05-28 | United States | Customer data exposed in Adidas cyber attack | Digital Watch Observatory.
#   - 2025-06-06 | England | Adidas Confirms Cyber-Attack; Customer Contact Data Exposed.
#
#  Topic ID: 75 - 17 articles
#   - 2025-04-30 | United States | PA schools use equity funds to cover rising cyber charter costs - Spotlight PA.
#   - 2025-05-03 | United States | Pennsylvania School Districts Use State Funds to Cover Rising Cyber Charter Costs.
#   - 2025-05-04 | United States | Reforming Cyber Charter Schools: New Bill Targets Accountability and Costs - MyChesCo.
#   - 2025-05-05 | United States | Overhaul to PA cyber charter school on the agenda for House after bipartisan calls for reform.
#   - 2025-05-05 | United States | Letter: Limit public funding for cyber charter schools - Scranton Times-Tribune.
#   - 2025-06-04 | United States | Cyber charter schools in Pennsylvania would see funding cut under bill passed by the state Hous.
#   - 2025-06-04 | United States | Public schools could send less money to PA's cyber charters - Spotlight PA.
#   - 2025-06-05 | United States | Pennsylvania's cyber charter schools would see funding cut under bill passed by Pa. House - WTA.
#   - 2025-06-05 | United States | Cyber Charter School Reform Bill Passes Pennsylvania House, Would Save School Districts ....
#   - 2025-06-05 | United States | Cyber charter reform bill clears Pennsylvania House - Chalkbeat.
#   - 2025-06-05 | United States | Cyber charter reform passed by Pa. House would save school districts millions of dollars.
#   - 2025-06-06 | United States | How cyber reforms in Pa. could impact the finances of your school - PennLive.com.
#   - 2025-06-06 | United States | Pa. House Passes Bill to Reform Cyber Charter School Funding - GovTech.
#   - 2025-06-06 | United States | PA Cyber Charter Reform Advances With Unclear Future - NewtownPANow.com.
#   - 2025-06-06 | United States | Cyber Charter Reform that Could Save Public Schools $616M Advances with Unclear ....
#   - 2025-06-07 | United States | Cyber charter schools would see funding cut under bill OK'd by Pa. state House.
#   - 2025-06-07 | United States | Pennsylvania House Passes Bill to Reform Cyber Charter Schools - MyChesCo.
#
#  Topic ID: 73 - 14 articles
#   - 2025-04-30 | England | Co-op becomes latest retailer hit by cyber incident - InternetRetailing.
#   - 2025-04-30 | England | Co-op forced to shut down IT system after cyber attack | Largs and Millport Weekly News.
#   - 2025-04-30 | England | Co-op Group targeted by cyber criminals in hacking attack | TheBusinessDesk.com.
#   - 2025-04-30 | England | Co-op shuts down IT systems following hack attempt - Digit.fyi.
#   - 2025-04-30 | England | Co-op shuts down parts of IT system following attempted cyberattack - Share Talk.
#   - 2025-04-30 | United States | Co-op Is Latest British Retailer to Be Hit by Cyber Attack - Insurance Journal.
#   - 2025-04-30 | United States | Co-op forced to shut down part of IT system after hack attempt - The Guardian.
#   - 2025-04-30 | England | Cyber attacks hit Co-op and M&S as police and experts investigate threats - Eastern Eye.
#   - 2025-04-30 | United States | Co-op forced to shut down part of IT system after cyber hack attempt - GB News.
#   - 2025-04-30 | England | Co-Op shuts down IT systems following cyber hack attempt - Tech Digest.
#   - 2025-04-30 | England | Co-op shuts off parts of IT system after attempted hack | ITV News.
#   - 2025-05-05 | United States | UK retailers under cyber attack: Co-op member data compromised - Help Net Security.
#   - 2025-05-06 | United States | Cyber attack on Co-op Group leaves stores with empty shelves - Co-operative News.
#   - 2025-05-18 | England | Co-op cyber hack latest as Midlands shoppers told of 'recovery' plan - all we know.
#
#  Topic ID: 84 - 12 articles
#   - 2025-05-01 | England | M&S and Co-op: UK retailers brace for cyber attacks - City AM.
#   - 2025-05-20 | England | Are cyber attacks about to become the norm for British retailers? - Yahoo Finance.
#   - 2025-05-30 | England | Cyber attacks see two thirds of UK consumers changing online shopping habits.
#   - 2025-05-30 | England | Editors' Top Reads: News from M&S, MOSS, AYM Studio and more... - TheIndustry.fashion.
#   - 2025-06-02 | England | Consumers Changing Online Shopping Habits Due To Recent Retail Cyber Attacks.
#   - 2025-06-03 | England | The North Face and Cartier latest to report being hit by retail cyber attacks.
#   - 2025-06-03 | England | The North Face and Cartier latest to face cyber-attacks - Digit.fyi.
#   - 2025-06-03 | England | North Face and Cartier customer data stolen in cyber attacks - Border Telegraph.
#   - 2025-06-03 | England | North Face and Cartier report stolen customer data in cyber attacks - Retail Week.
#   - 2025-06-04 | United States | North Face Latest Company Hit by Cyber Attacks; Adidas, Victoria's Secret, Struck in May.
#   - 2025-06-04 | Germany | North Face warns: Customer logins compromised by attack in April - It-daily.net.
#   - 2025-06-06 | United States | The North Face customers' personal information compromised in cyber attack | Fashion Dive.
#
#  Topic ID: 168 - 12 articles
#   - 2025-05-15 | United States | Coinbase expects up to $400 million hit from cyber attack - Yahoo Finance.
#   - 2025-05-15 | United States | Largest US crypto exchange hit by cyber-attack with costs expected of up to $400m.
#   - 2025-05-15 | England | Cyber attack: Coinbase warns of $400m hit after data breach - City AM.
#   - 2025-05-15 | United States | Coinbase stock drops after cyber attack and news of a SEC investigation - Yahoo Finance.
#   - 2025-05-15 | United States | Coinbase stock drops after cyber criminals swipe customer data and make $20 million ....
#   - 2025-05-15 | Germany | Crypto exchange Coinbase: data leak after cyber attack | heise online.
#   - 2025-05-15 | United States | Coinbase's cyber attack could cost it $400 million - Yahoo Finance.
#   - 2025-05-16 | England | Coinbase Faces $400M Loss After Cyber Attack - Finance Monthly.
#   - 2025-05-16 | England | Hackers breach Coinbase ahead of landmark S&P 500 entry - Digit.fyi.
#   - 2025-05-16 | England | Coinbase estimates $400M cost after data breach and crypto scam.
#   - 2025-05-16 | England | Cryptocurrency platform Coinbase warns of up to $400m hit from cyber attack.
#   - 2025-05-16 | England | Headaches at Coinbase: A data breach, a $20 million ransom demand, and a federal ....
#
#  Topic ID: 194 - 11 articles
#   - 2025-05-19 | England | Cyber attack on Legal Aid Agency exposed 'significant amount' of applicant data.
#   - 2025-05-19 | United States | Personal data taken in UK legal aid cyber attack, govt says - Yahoo! Tech.
#   - 2025-05-19 | England | Legal Aid Agency loses 'significant' amount of data to cyber-attack - Digit.fyi.
#   - 2025-05-19 | England | Huge cyber attack targets Legal Aid as names and personal details at risk - Yahoo News UK.
#   - 2025-05-19 | England | Cyber attack on UK legal aid agency exposes private data, including criminal records.
#   - 2025-05-19 | England | England: Huge volume of legal aid applicants' data stolen in cyber attack.
#   - 2025-05-19 | United States | Legal Aid Agency attack involved 'significant' data theft - The Register.
#   - 2025-05-19 | England | Legal aid cyber attack exposes sensitive applicant data dating back to 2010.
#   - 2025-05-19 | England | 'Significant amount' of data taken in cyber attack on Legal Aid Agency | ITV News.
#   - 2025-05-20 | England | Cyber attack on Legal Aid Agency exposes sensitive data - TechMarketView.
#   - 2025-06-04 | England | Legal Aid Agency cyber attackers said to be in 'known hacking group', court told.
#
#  Topic ID: 28 - 11 articles
#   - 2025-04-27 | Germany | Healthcare: Inadequate device security.
#   - 2025-04-28 | Germany | SAP: April updates close critical vulnerabilities - B2B Cyber Security.
#   - 2025-05-02 | Germany | Ballista: New IoT botnet attacks routers - B2B Cyber Security.
#   - 2025-05-13 | Germany | Samsung server software attacked by exploit - B2B Cyber Security.
#   - 2025-05-16 | Germany | Faulty ASUS software allows malware installations - B2B Cyber ??Security.
#   - 2025-05-16 | Germany | North Korean APT group uses Russian internet infrastructure - B2B Cyber Security.
#   - 2025-05-20 | Germany | Crypto platform refuses ransom and offers it as bounty - B2B Cyber ??Security.
#   - 2025-05-27 | Germany | IBM report: Continued attacks on critical economic sectors - B2B Cyber Security.
#   - 2025-05-30 | Germany | Operation Endgame 2.0 - B2B Cyber Security.
#   - 2025-06-05 | Germany | Firebase under fire - B2B Cyber Security.
#   - 2025-06-06 | Germany | Endgame 2.1: Cybercriminals lose virus testing engine AVCheck - B2B Cyber Security.
#
#  Topic ID: 269 - 9 articles
#   - 2025-05-29 | England | Victoria's Secret hit by 'security incident' - Drapers.
#   - 2025-05-29 | England | Victoria's Secret latest to be hit by security incident - Retail Systems.
#   - 2025-05-29 | England | Victoria's Secret shutters site following security incident - TheIndustry.fashion.
#   - 2025-05-29 | England | Victoria's Secret shuts down US website following 'security incident' - Tech Digest.
#   - 2025-05-29 | England | Victoria's Secret website is down in the US as the lingerie seller addresses a 'security incide.
#   - 2025-05-29 | United States | Victoria's Secret takes down U.S. website after "security incident" - CBS News.
#   - 2025-05-29 | England | Victoria's Secret shuts online store and limits services after security breach - EasternEye.
#   - 2025-05-30 | United States | Victoria's Secret Latest Hit in Growing Swath of Retail Cyber Attacks - Retail TouchPoints.
#   - 2025-05-31 | United States | Victoria's Secret hit by cyber incident amid retail breach surge - Tech Monitor.
#
#  Topic ID: 37 - 8 articles
#   - 2025-04-28 | United States | Blackouts in Spain and Portugal could be a cyber attack | IT Pro - ITPro.
#   - 2025-04-28 | Germany | Cyber attack? Massive power outage in Spain and Portugal - It-daily.net.
#   - 2025-04-28 | England | Massive power outages hit large parts of Spain and Portugal | ITV News.
#   - 2025-04-28 | England | Widespread power outages hit Spain, Portugal, France. Cyberattack can't be ruled out.
#   - 2025-04-28 | United States | "No indications" that cyber attack caused blackout in Spain and Portugal, says EU.
#   - 2025-04-28 | Germany | Spain, Portugal, and parts of France and Belgium remain without power - Weather - Vreme.
#   - 2025-04-29 | England | Power restored after widespread Iberian blackout - CIR Magazine.
#   - 2025-05-15 | Germany | Blackout in Spain and Portugal: what happened at the beginning | heise online.
#
#  Topic ID: 307 - 7 articles
#   - 2025-06-06 | United States | Fact Sheet: President Donald J. Trump Reprioritizes Cybersecurity Efforts to Protect America.
#   - 2025-06-06 | United States | Trump cyber executive order aims to amend 'problematic' parts of Biden, Obama cyber ....
#   - 2025-06-06 | United States | Trump issues cyber executive order revamping Biden-era mandates on software security ....
#   - 2025-06-06 | United States | Trump cyber executive order takes aim at prior orders, secure software, more | CyberScoop.
#   - 2025-06-07 | United States | Trump administration takes aim at Biden and Obama cybersecurity rules - TechCrunch.
#   - 2025-06-08 | United States | Trump Signs Order Amending Parts of Biden, Obama Cybersecurity Orders - NTD News.
#   - 2025-06-08 | United States | Trump Targets Obama-Biden Cyber Policies in New Executive Order Overhaul - CoinCentral.
#
#  Topic ID: 129 - 7 articles
#   - 2025-05-08 | United States | Cyber Defence & Resilience - Deloitte.
#   - 2025-05-12 | United States | Commvault and Deloitte Forge Strategic Alliance to Help Enhance Cyber Resilience and ....
#   - 2025-05-12 | United States | Commvault and Deloitte Partner to Boost Cyber Resilience and Incident Response for ... - MSSP A.
#   - 2025-05-13 | United States | Commvault and Deloitte partner to strengthen cyber resilience amid evolving threats.
#   - 2025-05-16 | United States | Commvault & Deloitte Join Forces on Cyber Resilience | Channel Insider.
#   - 2025-05-19 | United States | Commvault and Deloitte Collaborate to Strengthen Cyber Resilience and Incident Response.
#   - 2025-05-29 | United States | Cyber Defense & Resilience | Deloitte Caribbean and Bermuda.
#
#  Topic ID: 172 - 7 articles
#   - 2025-05-15 | United States | NHS asks suppliers to sign up to cyber covenant | Computer Weekly.
#   - 2025-05-16 | England | NHS calls on suppliers to improve their cybersecurity - Digit.fyi.
#   - 2025-05-16 | England | NHS suppliers urged to sign cyber security best practice charter - Digital Health.
#   - 2025-05-19 | England | NHS executives urge suppliers to sign cyber security charter - TechMarketView.
#   - 2025-05-19 | United States | NHS England launches cyber charter to shore up vendor security practices | IT Pro - ITPro.
#   - 2025-05-19 | England | NHS England launch Cyber Security Charter | techUK | Official Press Release - Wired-Gov.
#   - 2025-05-20 | England | NHS England launches cyber security charter to safeguard health sector.
#
#  Topic ID: 90 - 7 articles
#   - 2025-05-02 | United States | Trump proposes major cut to CISA's budget, citing false 'censorship' claims.
#   - 2025-05-03 | United States | Trump administration proposes cutting $491M from CISA budget - CyberScoop.
#   - 2025-05-05 | United States | Proposed Trump fiscal 2026 budget cuts CISA funding by $491 million to refocus agency mission.
#   - 2025-05-06 | United States | Trump would cut CISA budget by $491M amid 'censorship' claim - The Register.
#   - 2025-06-02 | United States | Trump's CISA budget lays out deep job cuts, program reductions | Cybersecurity Dive.
#   - 2025-06-02 | United States | US cyber agency CISA faces stiff budget cuts | Computer Weekly.
#   - 2025-06-03 | United States | Trump budget proposal would slash more than 1000 CISA jobs - CyberScoop.
#
#  Topic ID: 141 - 7 articles
#   - 2025-05-10 | United States | Cybersecurity Report 2025: Key Data Insights and Innovations.
#   - 2025-05-14 | England | Industrial Cybersecurity Global Market Forecasts Report 2025-2032 - Yahoo Finance.
#   - 2025-05-15 | United States | Industrial Cybersecurity Global Market Forecasts to 2032: Lucrative Opportunities in Cloud ....
#   - 2025-05-21 | England | Cybersecurity Market Use Cases, Solution Types and Industry Verticals 2025-2030.
#   - 2025-05-26 | United States | Cyber Security Market Industry Trends and Global Forecasts to 2035, Featuring AlgoSec ....
#   - 2025-05-26 | United States | Cybersecurity Market Report 2025-2030 - ResearchAndMarkets.com - Business Wire.
#   - 2025-05-30 | United States | Cyber Security Market Industry Report 2025 - ResearchAndMarkets.com - Business Wire.
#
#  Topic ID: 263 - 7 articles
#   - 2025-05-28 | United States | Leidos acquires cyber company Kudu Dynamics - Defense News.
#   - 2025-05-28 | United States | Leidos acquires Kudu Dynamics, advancing AI capabilities for cyber warfighters.
#   - 2025-05-28 | United States | Leidos acquires Kudu Dynamics for $300M to enhance AI-driven offensive cyber, EW capabilities.
#   - 2025-05-28 | United States | Leidos bets on offensive cyber with $300M Kudu acquisition - Washington Technology.
#   - 2025-05-29 | United States | Leidos Buys Cyber Firm Kudu Dynamics for $300M - GovCon Wire.
#   - 2025-05-29 | Germany | Leidos Buys Kudu Dynamics for $300M, Expands Cyber Capabilities - sharewise.
#   - 2025-05-30 | United States | Leidos acquires AI-enabled cyber capabilities company Kudu Dynamics.
#
#  Topic ID: 19 - 7 articles
#   - 2025-04-25 | United States | MTN Group experiences a cyber security obstacle - ITWeb Africa.
#   - 2025-04-27 | England | MTN Suffers Cyber Attack, Customers Data Exposed - MarketForces Africa.
#   - 2025-04-29 | England | 5,700 customers potentially affected as MTN Ghana probes cybersecurity breach.
#   - 2025-04-30 | England | Ministry of Communication provides update on MTN cybersecurity breach - Asaase Radio.
#   - 2025-04-30 | United States | MTN Ghana's cyber security exposure affects 5,700 customers - ITWeb Africa.
#   - 2025-05-04 | England | Call for full transparency and accountability on the MTN cyber security breach.
#   - 2025-05-04 | United States | MTN Ghana Cybersecurity Breach: Experts demand transparency and insider probe.
#
#  Topic ID: 12 - 7 articles
#   - 2025-04-24 | United States | CISA Releases Seven Industrial Control Systems Advisories.
#   - 2025-04-29 | United States | 5 ICS advisories released by CISA, security leaders discuss.
#   - 2025-04-29 | United States | CISA Releases Three Industrial Control Systems Advisories.
#   - 2025-05-08 | United States | CISA Releases Five Industrial Control Systems Advisories.
#   - 2025-05-15 | United States | CISA Releases Twenty-Two Industrial Control Systems Advisories.
#   - 2025-05-20 | United States | CISA Releases Thirteen Industrial Control Systems Advisories.
#   - 2025-05-27 | United States | CISA Releases One Industrial Control Systems Advisory.
#
#  Topic ID: 54 - 6 articles
#   - 2025-04-29 | United States | Marks & Spencer breach linked to Scattered Spider ransomware attack - Bleeping Computer.
#   - 2025-04-29 | England | Hacking group Scattered Spider linked to M&S cyber attack - Tech Digest.
#   - 2025-04-29 | United States | Cyberattack at Marks & Spencer involves Scattered Spider hackers - Tech Monitor.
#   - 2025-04-29 | England | M&S Rumoured to be Struggling Under Ransomware Attack | SC Media UK.
#   - 2025-04-29 | United States | Hacking group linked to Marks & Spencer cyberattack - The Times.
#   - 2025-04-30 | England | M&S cyber breach link to Scattered Spider ransomware - TechMarketView.
#
#  Topic ID: 93 - 6 articles
#   - 2025-05-03 | United States | Co-op apologises after hackers extract 'significant' amount of customer data - The Guardian.
#   - 2025-05-03 | England | Co-op issues apology after hackers get hands on members' personal data - City AM.
#   - 2025-05-03 | England | Co-op apologises after hackers access members' personal data - STV News.
#   - 2025-05-03 | England | Co-op apologises after members' personal data leaked during cyberattack | ITV News.
#   - 2025-05-03 | England | Co-op issues update after hackers access 'significant' amount of customers' data.
#   - 2025-05-04 | England | Co-op issues update after hackers access customers' data - The Hereford Times.
#
#  Topic ID: 76 - 6 articles
#   - 2025-04-30 | United States | Innovative Measures in Cybersecurity for 2025 - Security Boulevard.
#   - 2025-05-11 | United States | Driving Innovation with Enhanced NHIDR Capabilities - Security Boulevard.
#   - 2025-05-23 | United States | Optimistic Security: A New Era for Cyber Defense.
#   - 2025-05-24 | United States | Stay Reassured with Latest NHI Security Practices.
#   - 2025-05-27 | United States | How Free Are Your NHIs from Cyber Threats? - Security Boulevard.
#   - 2025-06-07 | United States | Why Securing NHIs Reduces Your Cyber Risk.
#
#  Topic ID: 140 - 6 articles
#   - 2025-05-10 | England | Edinburgh schools targeted in cyber attack as pupils passwords reset - Yahoo News UK.
#   - 2025-05-10 | England | Edinburgh schools hit by cyber attack targeting pupils as passwords reset - Yahoo News UK.
#   - 2025-05-10 | England | Thousands of pupils' reset passwords after schools targeted in cyber attack - STV News.
#   - 2025-05-10 | England | Thousands of pupils attend school after online phishing attack | The Herald.
#   - 2025-05-11 | United States | Thousands of pupils attend school on Saturday after online phishing attack - PA Media.
#   - 2025-05-12 | England | Thousands of Edinburgh Pupils Attend School on Saturday After Phishing Attack.
#
#  Topic ID: 284 - 6 articles
#   - 2025-06-01 | Germany | Phoenix Suns (Cyber) - Los Angeles Lakers (cyber) predictions, tips and statistics for 1 June 2.
#   - 2025-06-02 | Germany | Boston Celtics (cyber) - Milwaukee Bucks (cyber) predictions, tips and statistics for 2 June 20.
#   - 2025-06-04 | Germany | Los Angeles Clippers (cyber) predictions, statistics and betting tips for 4 June 2025.
#   - 2025-06-05 | Germany | Phoenix Suns (Cyber) betting predictions, odds and match statistics for 5 June 2025.
#   - 2025-06-07 | Germany | Dallas Mavericks (cyber) predictions, statistics and betting tips for 7 June 2025 - Leon.bet.
#   - 2025-06-07 | Germany | Indiana Pacers (Cyber) betting predictions and match preview for 7 June 2025 - Leon.bet.
#
#  Topic ID: 118 - 6 articles
#   - 2025-05-07 | England | West Lothian Council Suffering 'Suspected Criminal Ransomware Cyberattack'.
#   - 2025-05-07 | England | West Lothian Council schools hit by cyber-attack - Holyrood.
#   - 2025-05-09 | England | Investigation ongoing after West Lothian schools targeted in cyber attack | STV News.
#   - 2025-05-12 | England | Criminal investigation launched into cyber attack on West Lothian schools | STV News.
#   - 2025-05-23 | England | West Lothian school cyber attack 'obviously worrying' as investigation underway.
#   - 2025-05-26 | England | West Lothian school cyber attack 'obviously worrying' says councillor - Yahoo News UK.
#
#  Topic ID: 264 - 6 articles
#   - 2025-05-28 | United States | Chinese spies blamed for attempted hack on Czech government network.
#   - 2025-05-28 | United States | Czech Republic summons Chinese ambassador over cyber attacks - DW.
#   - 2025-05-28 | United States | China accused of 'malicious cyber campaign' targeting Czech foreign ministry.
#   - 2025-05-28 | Germany | From Prague to Wuhan: the Czech Republic accused China of long-term espionage - Vreme.
#   - 2025-05-29 | United States | Czechs Blame China for Cyberattack Against Foreign Ministry - Bloomberg.com.
#   - 2025-05-30 | United States | Czech Republic Accuses China of 'Malicious Cyber Campaign' Against Foreign Ministry.
#
#  Topic ID: 268 - 6 articles
#   - 2025-05-29 | England | Locate and destroy: Over £1bn to be spent on battlefield targeting system - Forces News.
#   - 2025-05-29 | England | UK to deliver pioneering battlefield system and bolster cyber warfare capabilities under ....
#   - 2025-05-29 | United States | UK military to establish new Cyber and Electromagnetic Command.
#   - 2025-05-29 | Germany | UK Cyber and Electromagnetic Command to be Established | Joint Forces News.
#   - 2025-05-30 | Germany | UK to Deliver Pioneering Battlefield System and Bolster Cybe - ASDNews.
#   - 2025-06-02 | England | Pioneering Battlefield System and Improved Cyber Warfare Capabilities Unveiled Under ....
#
#  Topic ID: 277 - 6 articles
#   - 2025-05-30 | United States | Texas Cyber Command Passes Texas Legislature.
#   - 2025-05-30 | United States | Governor Abbott Celebrates Texas Cyber Command Passing Texas Legislature.
#   - 2025-05-30 | United States | Governor Abbott launches Texas Cyber Command to combat global cyber threats.
#   - 2025-06-02 | United States | Governor Abbott in San Antonio expected to sign bill creating Texas Cyber Command.
#   - 2025-06-02 | United States | TODAY: Governor Abbott to sign bill establishing San Antonio cyber command center.
#   - 2025-06-02 | United States | Governor Abbott Signs Texas Cyber Command Into Law In San Antonio.
#
#  Topic ID: 8 - 5 articles
#   - 2025-04-24 | England | M&S: Shares at FTSE 100 retailer fall as cyber attack hits customers - City AM.
#   - 2025-04-25 | England | M&S: FTSE 100 shares slump as online orders stopped - City AM.
#   - 2025-04-28 | England | M&S: FTSE 100 shares continue to drop after cyber attack - City AM.
#   - 2025-04-29 | England | M&S: FTSE 100 shares start recovery after near-£700m cyber attack hit - City AM.
#   - 2025-05-13 | England | M&S: FTSE 100 shares rise after major cyber attack update - City AM.
#
#  Topic ID: 45 - 5 articles
#   - 2025-04-28 | United States | Forthcoming NIST profile to address growing AI-cyber challenges - Nextgov/FCW.
#   - 2025-04-28 | United States | NIST to develop AI guidance based on foundational security controls publication.
#   - 2025-05-22 | United States | Cybersecurity and AI: Integrating and Building on Existing NIST Guidelines.
#   - 2025-05-23 | United States | NIST outlines next steps for finding linkages between cyber and artificial intelligence through.
#   - 2025-05-28 | United States | NIST Creating New 'Cyber AI Profile,' Looking at AI Overlays - MeriTalk.
#
#  Topic ID: 57 - 5 articles
#   - 2025-04-29 | United States | In first, France accuses Russian intelligence of repeated cyber attacks - The Jerusalem Post.
#   - 2025-04-29 | Germany | France Accuses Russia of Cyber Attacks Targeting National Security - The Munich Eye.
#   - 2025-04-30 | Russia | France Accuses Russian Military Intelligence of Repeated Cyberattacks.
#   - 2025-04-30 | Germany | France accuses Russia of cyberattacks aimed at destabilization | heise online.
#   - 2025-05-04 | United States | France accuses Russia of cyberattacks on Olympic and election targets.
#
#  Topic ID: 106 - 5 articles
#   - 2025-05-05 | United States | Treasury Sanctions Burma Warlord and Militia Tied to Cyber Scam Operations.
#   - 2025-05-05 | England | Why a Warlord in Myanmar Is Responsible for That Scam Text on Your Phone - PCMag UK.
#   - 2025-05-06 | United States | US imposes sanctions on Myanmar ethnic militia for 'facilitating cyber scams' - ABC News.
#   - 2025-05-06 | United States | U.S. sanctions Myanmar warlord and militia tied to cyber scams - Crypto News.
#   - 2025-05-06 | United States | US sanctions Myanmar's ethnic Karen National Army for 'facilitating cyber scams' | Euronews.
#
#  Topic ID: 31 - 5 articles
#   - 2025-04-28 | United States | New Bill Mandates Cybersecurity Overhaul for Federal Contractors | Tripwire.
#   - 2025-05-24 | United States | Senators take another swing at vulnerability disclosure policy bill for federal contractors.
#   - 2025-05-27 | United States | Sens. Warner, Lankford reintroduce vulnerability disclosure bill to establish requirements for .
#   - 2025-05-28 | United States | Senators Reintroduce Federal Contractor Cybersecurity Bill - MeriTalk.
#   - 2025-05-28 | United States | Bipartisan bill revives effort to require cyber vulnerability disclosures from federal contract.
#
#  Topic ID: 162 - 5 articles
#   - 2025-05-14 | United States | Google says hackers behind UK retail cyber campaign now also targeting US.
#   - 2025-05-14 | United States | Hackers behind UK retail attacks now targeting US companies - Bleeping Computer.
#   - 2025-05-15 | England | Google Warns US Retailers Are Next Following UK Cyber-attacks - Digit.fyi.
#   - 2025-05-15 | England | Google: UK retail cyberattack wave set to spread to US - Retail Systems.
#   - 2025-05-15 | United States | Researchers warn threat actors in UK retail attacks are targeting US sector.
#
#  Topic ID: 148 - 5 articles
#   - 2025-05-12 | United States | CISA changes vulnerabilities updates, shifts to X and emails - The Register.
#   - 2025-05-13 | Germany | CISA realignment: warnings about known exploits now harder to find | heise online.
#   - 2025-05-13 | United States | CISA's alert pivot reflects a new era of decentralized cyber threat communication.
#   - 2025-05-15 | United States | CISA overturns modified cyber advisory dissemination plan | SC Media.
#   - 2025-05-19 | United States | CISA to Stop Publishing Cybersecurity Alerts and Advisories on Webpages - GBHackers.
#
#  Topic ID: 305 - 5 articles
#   - 2025-06-06 | England | Ransom note sent to M&S CEO reveals April hack details - Digit.fyi.
#   - 2025-06-06 | England | Hackers sent ransom demand directly to Marks & Spencer CEO - Retail Systems.
#   - 2025-06-06 | England | Cyberattack on Marks & Spencer: Hackers Target CEO in Bold Blackmail Attempt.
#   - 2025-06-06 | England | Abusive ransom email to M&S CEO reveals hackers demands - Tech Digest.
#   - 2025-06-06 | England | Marks & Spencer hackers sent abusive ransom demand to CEO - TheIndustry.fashion.
#
#  Topic ID: 304 - 5 articles
#   - 2025-06-06 | United States | New Cyber Blueprint to Scale Up the EU Cybersecurity Crisis Management | ENISA.
#   - 2025-06-06 | United States | EU Cyber Blueprint unifies crisis management, sets joint response framework, enhances ....
#   - 2025-06-06 | United States | EU takes a step further in cybersecurity crisis management | Shaping Europe's digital future.
#   - 2025-06-07 | United States | EU Adopts New Cyber Crisis Management Plan to Boost Digital Resilience - EUToday.
#   - 2025-06-08 | United States | The EU's Cybersecurity Blueprint and the Future of Cyber Crisis Management.
#
#  Topic ID: 102 - 5 articles
#   - 2025-05-05 | United States | Pak-Based Cyber Groups Target India Again, Multiple Defence Websites Hacked - NDTV.
#   - 2025-05-05 | United States | Cyber attacks from Pakistan target Indian defence websites amid escalating tensions.
#   - 2025-05-05 | United States | Pakistan-based cyber attackers target Indian defence websites, surveillance heightened to ....
#   - 2025-05-10 | United States | Major websites hacked as Pakistan launches cyber strike against Indian digital assets.
#   - 2025-05-10 | United States | Major Indian websites hacked in successful cyber attack by Pakistan.
#
#  Topic ID: 212 - 5 articles
#   - 2025-05-20 | United States | Article offers details on city of Abilene cyber attack, ransom.
#   - 2025-05-21 | United States | Russian group 'Qilin' claims Abilene data breach, demands ransom by May 27 - KTXS.
#   - 2025-05-21 | United States | City of Abilene says it will not pay ransom to cyber attackers.
#   - 2025-05-23 | United States | Russian group 'Qilin' demands ransom by next week, City of Abilene refuses to pay - KTXS.
#   - 2025-06-02 | United States | City of Abilene continues to strengthen cyber defenses after ransomware attack - KTXS.
#
#  Topic ID: 219 - 5 articles
#   - 2025-05-21 | England | UK, Allies Expose Russian Cyber Espionage Targeting Ukraine Aid Networks - Arise News.
#   - 2025-05-21 | England | UK and allies expose Russian cyber attacks on logistics firms aiding Ukraine.
#   - 2025-05-22 | United States | UK exposes Russian cyber campaign targeting support for Ukraine - Yahoo.
#   - 2025-05-23 | England | UK exposes Russian cyber campaign targeting Ukraine aid - Tech Digest.
#   - 2025-05-23 | England | UK exposes 'malicious' Russian cyber campaign targeting western defence - Holyrood.
#
#  Topic ID: 210 - 5 articles
#   - 2025-05-20 | United States | Cyberattack brings down Kettering Health phone lines, MyChart patient portal access.
#   - 2025-05-21 | United States | Cyberattack forces outage, influx of scam calls impacting Kettering Health - WCPO.
#   - 2025-05-21 | United States | Ransomware suspected in Kettering Health cyberattack disrupting patient services ....
#   - 2025-05-26 | United States | Kettering Health confirms cyberattack involves ransomware, calls incident 'jarring' - WLWT.
#   - 2025-06-06 | United States | Kettering Health confirms attack by Interlock ransomware group as health record system is resto.
#
#  Topic ID: 213 - 5 articles
#   - 2025-05-20 | United States | Assumption University student agrees to plead guilty to cyber-extorting companies.
#   - 2025-05-20 | United States | Worcester College Student to Plead Guilty to Cyber Extortions - Department of Justice.
#   - 2025-05-21 | United States | Assumption University student to plead guilty to cyber extortions, prosecutors say - The Boston.
#   - 2025-05-21 | United States | Worcester college student pleads guilty to cyber crimes - Boston.com.
#   - 2025-06-06 | United States | Assumption College freshman pleads guilty to cyber extortion charges - WHDH.
#
#  Topic ID: 214 - 5 articles
#   - 2025-05-20 | England | M&S CEO Stuart Machin to face over £1million pay cut following cyber attack - Tech Digest.
#   - 2025-06-02 | United States | M&S boss's pay package soared to £7.1m weeks before cyber-attack - The Guardian.
#   - 2025-06-02 | England | Marks & Spencer boss's pay deal surges to £7.1m - The National.
#   - 2025-06-02 | United States | M&S boss's pay jumps to £7m as retailer battles cyber attack - Yahoo Finance.
#   - 2025-06-02 | England | Marks & Spencer boss's pay deal surges to £7.1m - TheIndustry.fashion.

# %% [markdown]
# #### <div dir="rtl">חלק 5: מגמות פרסום לנושאים מובילים – גרף יומי וממוצע נע</div>
# <div dir="rtl">
# בקטע זה, עבור כל אחד מחמשת הנושאים המרכזיים, סופרים את מספר המאמרים שפורסמו בכל יום, מחשבים ממוצע נע בן יומיים, ומשרטטים גרף המציג גם את המספרים האמיתיים בכל יום וגם את המגמה (moving average).
# כך ניתן לראות בצורה ויזואלית איך פורסמו מאמרים בכל נושא לאורך זמן ולאתר מגמות או שיאים בולטים.
# </div>

# %%
topic_sizes  = topic_df['topic_id'].value_counts()
large_topics = [t for t, sz in topic_sizes.items() if sz >= 5]

# 2️⃣ מתוך אלה – השאר רק מי שמתפרס על לפחות 3 ימים שונים
eligible = [
    t for t in large_topics
    if topic_df.loc[topic_df['topic_id']==t, 'published_date'].nunique() >= 3
]

# 3️⃣ מיין את ה־eligible לפי גודל אשכול (יורד) ובחר 5 ראשונים
eligible.sort(key=lambda t: topic_sizes[t], reverse=True)
top5_topics = eligible[:5]
print("Plotting trends for these 5 topics:", top5_topics)

# 4️⃣ לולאת השרטוט – עבור כל אחד מה־top5
for topic in top5_topics:
    subset      = topic_df[topic_df['topic_id'] == topic]
    # 4.1 ספירת כתבות לפי יום, ממוינת כרונולוגית
    topic_dates = subset['published_date'].value_counts().sort_index()
    # 4.2 ממוצע נע בן יומיים
    ma          = topic_dates.rolling(window=2).mean()

    # הפיכת אינדקסי התאריכים למחרוזות 'YYYY-MM-DD' להצגה על הציר
    dates      = topic_dates.index.strftime('%Y-%m-%d')
    ma_dates   = ma.index.strftime('%Y-%m-%d')

    # 4.3 יצירת הגרף
    plt.figure(figsize=(10, 5))
    plt.plot(  dates,      topic_dates.values, marker='o', label='Actual')
    plt.plot( ma_dates,    ma.values,          linestyle='--', label='2-day MA')
    plt.title(f"Topic ID {topic} | {len(topic_dates)} Days | {len(subset)} Articles", fontsize=12)
    plt.xlabel("Date", fontsize=10)
    plt.ylabel("Number of Articles", fontsize=10)
    plt.xticks(rotation=45, ha='right')
    plt.legend()
    plt.grid(True, linestyle=':', linewidth=0.7)
    plt.tight_layout()
    plt.show()
# Out:
# Plotting trends for these 5 topics: [7, 82, 251, 75, 73]

# %% [markdown]
# #### <div dir="rtl">חלק 6: השוואה בין מאמרים ייחודיים למאמרים עם כפילויות</div>
# <div dir="rtl">
# בקטע זה מחשבים כמה מאמרים אין להם אף מאמר דומה ("ייחודיים") וכמה יש להם כפילויות (כלומר, דומים לאחרים), ומציגים גרף עמודות המשווה בין שתי הקבוצות – כולל אחוזים ומספרים מוחלטים לכל קטגוריה.
# </div>

# %%
counts = posted_df['similar_count'].eq(0).value_counts().rename(index={True: 'Unique (0)', False: 'With duplicates (>0)'})
percent = (counts / counts.sum() * 100).round(1)

fig, ax = plt.subplots(figsize=(14, 8))
bars = ax.bar(counts.index, counts.values, color=['steelblue', 'salmon'], edgecolor='black')

for bar, pct, n in zip(bars, percent, counts):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 3,
            f'{pct} %\n(n={n})', ha='center', va='bottom', fontsize=10)

ax.set_title('Unique vs. Duplicate Articles', fontsize=14, pad=10)
ax.set_ylabel('Number of Articles')
sns.despine(); plt.tight_layout(); plt.show()

# %% [markdown]
# # <div dir="rtl">🔹שלב 5: איגוד תקצירי נושאים והנדסת מאפייני מגמה</div>
# <div dir="rtl">
# בשלב זה מאחדים את כל האשכולות ל־topics_df המרכזי, מחשבים וממפים מדדי מגמה עיקריים (מספר ימי פעילות, מקסימום מאמרים ביום, זיהוי "ספייק" או צמיחה), מסווגים את סוג המגמה של כל נושא (Spike/Growth/Both/None), ומאתרים את יום הפרסום הדומיננטי עבור כל נושא.
# </div>

# %% [markdown]
# #### <div dir="rtl">חלק 1: בניית DataFrame מרכזי של נושאים (topics_df) על סמך איגוד מאפיינים עיקריים</div>
# <div dir="rtl">
# בקטע זה מאגדים לכל אשכול (נושא) את המטא-דאטה המרכזית: מספר המאמרים באשכול, תאריכי הפרסום הראשון והאחרון, המדינה/מקור העיקרי, חמש מילות המפתח הבולטות, וכותרת מייצגת קצרה.
# </div>

# %%
topics_df = (
    topic_df.sort_values('published_date').groupby('topic_id').agg(
    num_articles=('ID', 'count'),  
    first_date=('published_date', 'min'), 
    last_date=('published_date', 'max'),  
    main_country=('rss_source', lambda x: x.mode()[0] if not x.mode().empty else None), 
    top_keywords=('cleaned_keywords', lambda x: ', '.join(pd.Series([kw for kws in x for kw in kws]).value_counts().head(5).index)),
    short_title=('title', 'first')
).reset_index())

# %% [markdown]
# #### <div dir="rtl">חלק 2: חישוב מדדי מגמה עבור כל נושא</div>
# <div dir="rtl">
# בקטע זה מחשבים לכל נושא (אשכול) את מספר ימי הפרסום השונים (`topic_day_counts`), את המספר המקסימלי של מאמרים שפורסמו ביום אחד (`max_articles_per_day`), ומגדירים דגלים בוליאניים (True/False) לזיהוי אירועי "ספייק" (לפחות 4 מאמרים ביום) ושלבי צמיחה (נוכחות בלפחות 3 ימים שונים).
# </div>

# %%
topic_day_counts = topic_df.groupby('topic_id')['published_date'].nunique() 

max_articles_per_day = (topic_df.groupby(['topic_id', 'published_date']).size().groupby('topic_id').max()) 

spike_condition = max_articles_per_day >= 4     
growth_condition = topic_day_counts >= 3

# %% [markdown]
# #### <div dir="rtl">חלק 3: מיפוי מדדי מגמה לכל נושא ב־topics_df</div>
# <div dir="rtl">
# בקטע זה ממפים את מדדי המגמה שחושבו לכל נושא אל טבלת הנושאים הראשית (`topics_df`), ומוסיפים עמודות חדשות: מספר ימי פעילות, מקסימום מאמרים ביום, ודגלים לזיהוי "ספייק" ולשלב צמיחה, לפי מזהה הנושא (topic_id).
# </div>

# %%
topics_df['num_days'] = topics_df['topic_id'].map(topic_day_counts)
topics_df['max_articles_per_day'] = topics_df['topic_id'].map(max_articles_per_day)
topics_df['spike_detected'] = topics_df['topic_id'].map(spike_condition) 
topics_df['growth_detected'] = topics_df['topic_id'].map(growth_condition)

# %% [markdown]
# #### <div dir="rtl">חלק 4: הנדסת מאפייני מגמה וסיכום נושא</div>
# <div dir="rtl">
# בקטע זה מאגדים את כל האשכולות אל תוך topics_df, ממפים את מדדי המגמה שחושבו (מספר ימי פעילות, מקסימום מאמרים ביום, דגלי Spike ו־Growth), מסווגים את סוג המגמה לכל נושא (Spike / Growth / Both / None) לפי השילוב בין הדגלים, ומאתרים עבור כל נושא את יום הפרסום הדומיננטי ביותר.
# </div>

# %%
def classify_trend(spike, growth):
    if spike and growth:
        return 'Both'
    elif spike:
        return 'Spike'
    elif growth:
        return 'Growth'
    else:
        return 'None'

topics_df['trend_type'] = topics_df.apply(
    lambda row: classify_trend(row['spike_detected'], row['growth_detected']),
    axis=1
)

dominant_day = (topic_df.groupby(['topic_id', 'published_date']).size()
                        .groupby('topic_id').idxmax()  
                        .apply(lambda x: x[1])) 

topics_df['dominant_day'] = topics_df['topic_id'].map(dominant_day)

# %% [markdown]
# # <div dir="rtl">🔹שלב 6: סיום סיכומים והכנסה למסד הנתונים</div>
# <div dir="rtl">
# בשלב זה מאחדים את טבלת סיכום הנושאים הסופית ומכניסים כל נושא, מאמר ומגמת טרנד חדשים אל הטבלאות המתאימות במסד הנתונים.
# </div>

# %% [markdown]
# #### <div dir="rtl">חלק 1: בחירה וסידור סופי של עמודות בתמצית הנושאים</div>
# <div dir="rtl">
# בקטע זה בוחרים ומסדרים מחדש את העמודות המרכזיות ב־ topics_df, מתמקדים בשדות סיכום ומגמה עיקריים, ומציגים את השורות הראשונות כדי לוודא את מבנה הטבלה.
# </div>

# %%
topics_df = topics_df[[
    'topic_id', 'short_title', 'trend_type',
    'num_articles', 'num_days', 'max_articles_per_day',
    'first_date', 'dominant_day', 'last_date', 'main_country',
    'top_keywords', 'spike_detected', 'growth_detected']]

print(topics_df.head())
# Out:
#    topic_id                                        short_title trend_type  \
# 0         0  FBI: Cybercrime cost victims 'staggering' $16....       None
# 1         1  Thales and Deloitte align to offer advanced cy...       None
# 2         2  TOKYO, Apr 24, 2025 - NEC Corporation (NEC; TS...       None
# 3         3  Not just any cyber incident...but an M&S cyber...     Growth
# 4         4  Benchmarking Standard for Securing AI Systems ...       None
#
#    num_articles  num_days  max_articles_per_day first_date dominant_day  \
# 0             3         2                     2 2025-04-24   2025-04-24
# 1             2         2                     1 2025-04-23   2025-04-23
# 2             2         2                     1 2025-04-24   2025-04-24
# 3             3         3                     1 2025-04-23   2025-04-23
# 4             2         2                     1 2025-04-23   2025-04-23
#
#    last_date   main_country  \
# 0 2025-04-28  United States
# 1 2025-04-25  United States
# 2 2025-04-28        England
# 3 2025-05-15        England
# 4 2025-05-31        England
#
#                                         top_keywords  spike_detected  \
# 0   cyber, criminal, yarbrough, director, operations           False
# 1  acceleration, digital, transformation, require...           False
# 2  hereafter, geodesic, strengthening, business, ...           False
# 3        cyber, issued, update, customers, following           False
# 4           raywood, cyber, threats, written, senior           False
#
#    growth_detected
# 0            False
# 1            False
# 2            False
# 3             True
# 4            False

# %% [markdown]
# #### <div dir="rtl">חלק 2: שמירת נושאים חדשים למסד הנתונים</div>
# <div dir="rtl">
# בקטע זה טוענים את מזהי הנושאים הקיימים, מסננים החוצה נושאים שכבר קיימים במסד הנתונים, ומוסיפים רק את סיכומי הנושאים החדשים מתוך topics_df לטבלת Topics.
# </div>

# %%
existing_topics = pd.read_sql("SELECT topic_id FROM Topics", con=engine)
topics_df_filtered = topics_df[~topics_df['topic_id'].isin(existing_topics['topic_id'])]

if not topics_df_filtered.empty:  # If there are new topics to insert
    topics_df_filtered.to_sql('Topics', con=engine, index=False, if_exists='append')
    print(f"✅ Topics saved: {len(topics_df_filtered)}") 
else:
    print("ℹ️ No new topics to insert.")
# Out:
# ✅ Topics saved: 310

# %% [markdown]
# #### <div dir="rtl">חלק 3: הכנה ושמירה של מאמרים</div>
# <div dir="rtl">
# בקטע זה בוחרים עמודות מרכזיות מתוך topic_df (כולל שינוי שם ID ל־article_id וסידור מילות מפתח), מסננים החוצה מאמרים שכבר קיימים בטבלת Articles, ומוסיפים רק את המאמרים החדשים למסד הנתונים.
# </div>

# %%
articles_df = topic_df[[
    'ID', 'title', 'summary', 'url',
    'published_date', 'published_time', 'rss_source',
    'cleaned_keywords','topic_id', 'similar_count']].copy()

articles_df.rename(columns={'ID': 'article_id'}, inplace=True) 
articles_df['cleaned_keywords'] = articles_df['cleaned_keywords'].apply(lambda kws: ', '.join(kws) if isinstance(kws, list) else '') 
print(articles_df[["title","published_date"]].sort_values('published_date', ascending = False).head())


existing_articles = pd.read_sql("SELECT article_id FROM Articles", con=engine) 
articles_df_filtered = articles_df[~articles_df['article_id'].isin(existing_articles['article_id'])]  

if not articles_df_filtered.empty: 
    articles_df_filtered.to_sql('Articles', con=engine, index=False, if_exists='append')  
    print(f"✅ Articles saved: {len(articles_df_filtered)}")
else:
    print("ℹ️ No new articles to insert.")
# Out:
#                                                   title published_date
# 4824  Trump Targets Obama-Biden Cyber Policies in Ne...     2025-06-08
# 4820  North Korea wiped off the internet for 9 hours...     2025-06-08
# 4814  Cyber Police Kashmir Issues Stern Warning Agai...     2025-06-08
# 4806  Trump Signs Order Amending Parts of Biden, Oba...     2025-06-08
# 4796  The EU's Cybersecurity Blueprint and the Futur...     2025-06-08
# ✅ Articles saved: 1036

# %% [markdown]
# #### <div dir="rtl">חלק 4: הכנה ושמירה של מגמות (Trends)</div>
# <div dir="rtl">
# בקטע זה מסננים את הנושאים בטבלת topics_df לפי מגמה שזוהתה (trend_type שונה מ־'None'), משייכים לכל מגמה תקציר מאמר מייצג, מסננים מגמות שכבר נשמרו בטבלת Trends, ומוסיפים רק את המגמות החדשות למסד הנתונים.
# </div>

# %%
trends_df = topics_df[topics_df['trend_type'] != 'None'].copy() 

topic_summary_map = ( 
    articles_df
    .sort_values(['topic_id', 'published_date'], ascending=[True, True]) 
    .drop_duplicates('topic_id') 
    .set_index('topic_id')['summary']
)

trends_df['representative_summary'] = trends_df['topic_id'].map(topic_summary_map) 

print(trends_df[["short_title","trend_type","first_date"]].head())

existing_trends = pd.read_sql("SELECT topic_id FROM Trends", con=engine) 
trends_df_filtered = trends_df[~trends_df['topic_id'].isin(existing_trends['topic_id'])] 

if not trends_df_filtered.empty:
    trends_df_filtered.to_sql('Trends', con=engine, index=False, if_exists='append')
    print(f"✅ Trends saved: {len(trends_df_filtered)}")
else:
    print("ℹ️ No new trends to insert.")
# Out:
#                                           short_title trend_type first_date
# 3   Not just any cyber incident...but an M&S cyber...     Growth 2025-04-23
# 7   M&S takes systems offline as 'cyber incident' ...       Both 2025-04-24
# 8   M&S: Shares at FTSE 100 retailer fall as cyber...     Growth 2025-04-24
# 12  CISA Releases Seven Industrial Control Systems...     Growth 2025-04-24
# 19  MTN Group experiences a cyber security obstacl...     Growth 2025-04-25
# ✅ Trends saved: 62

# %% [markdown]
# # <div dir="rtl">🔸 שלב 7: ויזואליזציה של מגמות הסייבר המובילות</div>
# <div dir="rtl">
# בשלב זה מוצגים ארבעה גרפים משלימים לניתוח המגמות הבולטות:
# - תרשים עמודות של 10 הנושאים המובילים לפי כמות מאמרים
# - גרף קווים של מגמות פרסום יומיומיות (כולל שטח צל וציוני שיאים)
# - ענן מילים של מילות המפתח השכיחות ביותר במגמות
# - תרשים עמודות אופקי מפורט לשבעת המגמות הבולטות, עם תקצירים, תאריכים ומטא־דאטה עיקרי
# </div>

# %% [markdown]
# #### <div dir="rtl"> 🔸גרף 1: בחירה והמחשה של עשרת הנושאים החמים ביותר ממיינים את טבלת המגמות (trends_df) לפי מספר המאמרים ומספר ימי הפעילות כדי לבחור את עשרת הנושאים הבולטים, ממפים כל מזהה נושא לכותרת קצרה, ובונים תרשים עמודות הממחיש את מספר המאמרים עבור כל נושא מוביל. </div>
# <div dir="rtl"> <strong>הסבר על התהליך:</strong> </div>
# <div dir="rtl">
# הקוד ממיין את טבלת המגמות בסדר יורד לפי כמות המאמרים והימים הפעילים, שומר את עשרת הנושאים המובילים, ובונה מילון מזהה-כותרת. לאחר מכן, יוצר תרשים עמודות (barplot) בו כל עמודה מייצגת נושא מוביל, ציר X הוא כותרות הנושאים, וציר Y הוא מספר המאמרים בכל נושא. כך מתקבלת תמונה ברורה של עשרת הנושאים שסוקרו הכי הרבה. </div>
#
# <div dir="rtl"> <strong>ניתוח הפלט:</strong>הגרף מדגים פער משמעותי בין הנושא המוביל – שקיבל כמעט פי ארבעה או יותר מאשר הנושאים הבאים אחריו – לבין שאר עשרת הנושאים המובילים. הנושא הבולט בגרף עוסק ככל הנראה באירוע סייבר משמעותי במיוחד, שתפס את עיקר תשומת הלב התקשורתית והוביל לכמות סיקור חריגה. ניתן לראות שהיתר, למרות שמדובר בנושאים חמים, קיבלו סיקור נמוך בהרבה וההבדלים ביניהם קטנים יחסית. התובנה המרכזית: סדר היום התקשורתי בתחום הסייבר נשלט לעיתים קרובות על ידי אירועים בודדים, בעוד ששאר הנושאים – חשובים ככל שיהיו – נדחקים לשוליים. גרף זה חיוני למנהלי סייבר, אנליסטים וחוקרים כדי להתמקד בנושאים בעלי החשיפה הגבוהה ביותר ולזהות בזמן אמת "ספייקים" במדיה סביב מתקפות גדולות. </div>

# %%
top_trends = trends_df.sort_values(['num_articles', 'num_days'], ascending=False).head(10 )
top_topic_ids = top_trends['topic_id'].tolist()
id_to_title = dict(zip(top_trends['topic_id'], top_trends['short_title']))

plt.figure(figsize=(16, 8))
sns.barplot(
    data=top_trends, 
    x='short_title',
    y='num_articles',
    hue='short_title',
    palette='viridis',
    legend=False
)
plt.title('Top 10 Trending Topics by Number of Articles', fontsize=17, fontweight='bold', color='#2a2e38')
plt.xlabel('Topic', fontsize=13, fontweight='bold')
plt.ylabel('Number of Articles', fontsize=13, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=10)# plt.grid(axis='y')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### <div dir="rtl"> 🔸גרף 2: המחשת מגמות פרסום יומיות לנושאים החמים ביותר מחשבים את מספר המאמרים שפורסמו בכל יום עבור כל אחד מהנושאים החמים, משייכים צבע ייחודי לכל נושא, ובונים גרף קווים שבו כל קו מייצג נושא שונה. בנוסף, צובעים שטח מתחת לכל קו ומסמנים את נקודות השיא (כאשר פורסמו 10 מאמרים או יותר) כדי להדגיש דינמיקת פרסום לאורך זמן. </div>
#
# <div dir="rtl"> <strong>ניתוח הפלט:</strong> הגרף מדגים בצורה ברורה את מגמות הפרסום היומי של עשרת הנושאים החמים ביותר. רואים שלחלק מהנושאים יש "התפוצצות" פתאומית בכמות הפרסומים ביום מסוים (שיאים של 21–22 מאמרים ביום בודד), ואחריהם חזרה לרמות נמוכות הרבה יותר. נושאים אחרים מציגים דפוס יציב יחסית, ללא שיאים דרמטיים. הקווים הצבעוניים והשטחים המודגשים מתחת לכל קו מדגישים את העוצמה והרצף של כל נושא לאורך זמן. המשמעות: הגרף עוזר לזהות האם נושא מסוים קיבל תשומת לב פתאומית (ספייק), האם מדובר בעניין ממושך, והאם יש נושאים שזוכים לסיקור עקבי לעומת כאלה שמופיעים פתאום ונעלמים. בזכות כך, ניתן להעריך האם מדובר בטרנד חולף, באירוע חד-פעמי משמעותי, או במגמה מתמשכת בתחום הסייבר. </div>

# %%
sns.set_theme(style="whitegrid", font_scale=1.05)
mask = topic_df['topic_id'].isin(top_topic_ids)
daily_counts = (topic_df.loc[mask]
                .groupby(['topic_id', 'published_date'])
                .size()
                .reset_index(name='count')
                .merge(topics_df[['topic_id', 'short_title']], on='topic_id'))

daily_counts = daily_counts.sort_values('published_date')


palette = sns.color_palette('tab10', n_colors=len(top_topic_ids))
colours = {tid: palette[i] for i, tid in enumerate(top_topic_ids)}


fig, ax = plt.subplots(figsize=(24, 12))

for tid in top_topic_ids:
    sub = daily_counts[daily_counts['topic_id'] == tid]

    ax.plot(sub['published_date'], sub['count'],
        marker='o', linewidth=2, color=colours[tid], label=sub['short_title'].iloc[0][:70] + '…')

    ax.fill_between(sub['published_date'],
                sub['count'], color=colours[tid], alpha=.08)

    for x, y in zip(sub['published_date'], sub['count']):
        if y >= 10:
            ax.text(x, y + 0.4, f'{y}', ha='center',
                    fontsize=9, color=colours[tid])

ax.set_title('Daily Article Count for Top Trending Topics', fontsize=28, pad=12)
ax.set_xlabel('Date')
ax.set_ylabel('Number of Articles')
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
ax.legend(title='Topics', frameon=False, loc='upper left')
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### <div dir="rtl"> 🔸גרף 3: ענן מילים של מילות המפתח במגמות החמות מאחדים את כל מילות המפתח המרכזיות מתוך הנושאים החמים ביותר לטקסט אחד, ומייצרים ענן מילים (Word Cloud) שממחיש בצורה ויזואלית אילו מילות מפתח מופיעות הכי הרבה ומשפיעות על מגמות הסייבר העדכניות. </div>
#
# <div dir="rtl"> <strong>ניתוח הפלט:</strong> ענן המילים מדגיש בבירור שמילות הליבה של מגמות הסייבר הן cyber, security, attack, ו-cybersecurity – כלומר, רוב הכתבות והאירועים עוסקים ישירות באבטחת מידע, מתקפות סייבר ותגובות לאיומים. ניתן לראות גם בולטים מושגים משניים כמו incident, ransomware, defense, information, health, group, ו-national, שמעידים על נושאים חוזרים: מתקפות כופרה, אירועים לאומיים, סוגיות בריאותיות, דליפות מידע ושחקנים בולטים בזירה. המשמעות: מיפוי מהיר של מושגי המפתח מסייע לזהות לא רק את מגמות הסייבר, אלא גם את סוגי האיומים, הענפים הנפגעים וההקשרים הרחבים (כמו ממשלות, בריאות, מגזר קמעונאי). גרף זה מהווה כלי יעיל לאנליסטים ולמנהלים להבין מיד מהם הנושאים החמים ומהיכן צומחות מגמות חדשות בשיח התקשורתי והמקצועי. </div>

# %%
trend_keywords_series = trends_df['top_keywords'].dropna().astype(str)
text_blob = ' '.join(trend_keywords_series)

wordcloud = WordCloud(width=1000, height=600, background_color='white', colormap='mako',contour_width=2,
    contour_color='steelblue',stopwords=stopwords).generate(text_blob)

plt.figure(figsize=(12, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Top Keywords in Trending Topics (WordCloud)', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### <div dir="rtl"> 🔸גרף 4: המחשת 7 המגמות המובילות עם תקצירים מפורטים לשבעת הנושאים המרכזיים ביותר, עוטפים את תקציר המאמר המייצג, מפיקים את מילות המפתח המרכזיות, ומשרטטים תרשים עמודות אופקי של כמות המאמרים. כל עמודה מלווה בתיאור קצר שמציג את סוג המגמה, מספר הכתבות, ימי פעילות, היום הדומיננטי, המדינה ומילות המפתח – הכל במטרה לאפשר פרשנות מהירה וברורה. </div>
#
# <div dir="rtl"> <strong>ניתוח הפלט:</strong> הגרף האופקי מציג בבירור את שבע מגמות הסייבר המובילות, כולל תקציר מפורט של כל מגמה ונתוני עומק בצמוד לכל עמודה. ניתן לראות מגמה אחת ששולטת באופן מובהק (87 מאמרים ב-14 ימים, שיא יומי של 22), העוסקת בפריצת סייבר לרשת קמעונאות – עם מילות מפתח חוזרות כמו spencer, cyber, attack, marks, online. שאר המגמות נמצאות הרחק מאחור – כל אחת מתאפיינת בשילוב אחר של נושאים: מתקפת סייבר על חברת אופנה, פרצת נתונים בענקית תשלומים, נושאי ביטחון לאומי, תשלומי כופר (ransomware) ועוד. לכל מגמה מוצגות אינפורמציה על מספר כתבות, ימי פעילות, יום שיא, מדינה דומיננטית ומילות מפתח – נתונים שמסייעים להבין במהירות את מאפייני כל מגמה ואת הדינמיקה שלה. המשמעות: גרף זה מאפשר זיהוי מידי של מגמות על פי נפח התקשורת, הבנה של הקשרים מרכזיים, והשוואה בין עוצמתן של תופעות סייבר שונות בשוק הגלובלי. </div>

# %%
top_topic_ids = trends_df.sort_values(['num_articles', 'num_days'], ascending=False).head(7)['topic_id']
top_articles = articles_df[articles_df['topic_id'].isin(top_topic_ids)].copy()
if isinstance(top_articles['cleaned_keywords'].iloc[0], list):
    top_articles['cleaned_keywords'] = top_articles['cleaned_keywords'].apply(lambda x: ' '.join(x))

topic_keywords = top_articles.groupby('topic_id')['cleaned_keywords'].apply(lambda x: ' '.join(x))
vec = CountVectorizer()
X = vec.fit_transform(topic_keywords)
keyword_matrix = pd.DataFrame(X.toarray(), index=topic_keywords.index, columns=vec.get_feature_names_out())

def get_top5_keywords(row):
    topic_id = row['topic_id']
    if topic_id in keyword_matrix.index:
        top_words = keyword_matrix.loc[topic_id].sort_values(ascending=False).head(5)
        top_words = top_words[top_words > 0]
        return ', '.join([f"{word} ({count})" for word, count in top_words.items()])
    else:
        return "N/A"

def wrap_summary(text, max_len=100, max_lines=7):
    words = text.split()
    lines = []
    line = ""
    for word in words:
        if len(line + " " + word) <= max_len:
            line += " " + word
        else:
            lines.append(line.strip())
            line = word
            if len(lines) == max_lines:
                break
    if line and len(lines) < max_lines:
        lines.append(line.strip())
    return '\n'.join(lines)

top7 = trends_df[trends_df['topic_id'].isin(top_topic_ids)].sort_values(by=['num_articles', 'num_days'], ascending=False).copy()

top7['wrapped_title'] = top7['representative_summary'].apply(wrap_summary)
top7['top5_keywords'] = top7.apply(get_top5_keywords, axis=1)

top7['label'] = top7.apply(lambda row: (
    f"Trend Type: {row['trend_type']}\n"
    f"Articles: {row['num_articles']} | Days: {row['num_days']}\n"
    f"Max per Day: {row['max_articles_per_day']}\n"
    f"Dominant Day: {row['dominant_day']}\n"
    f"Country: {row['main_country']}\n"
    f"Top Keywords: {row['top5_keywords']}"
), axis=1)


colors = plt.cm.tab10.colors
bar_colors = [colors[i % len(colors)] for i in range(len(top7))]

fig, ax = plt.subplots(figsize=(16, 10))
bars = ax.barh(top7['wrapped_title'], top7['num_articles'], color=bar_colors)

for bar, label in zip(bars, top7['label']):
    ax.text(
        bar.get_width() + 0.5,
        bar.get_y() + bar.get_height()/2,
        label,
        va='center',
        ha='left',
        fontsize=10,
        color='dimgray'
        , fontweight='bold'
    )

ax.set_title("Top 7 Cyber Trends – Based on Most Representative Article Summary", fontsize=16, fontweight='bold')
ax.set_xlabel("Number of Articles", fontsize=14, fontweight='bold')
ax.set_ylabel("Representative Summary", fontsize=14, fontweight='bold')
ax.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout(rect=[0, 0, 0.97, 1]) 
plt.show()
